# %% [markdown]
# ### 3 1 1 시장 분석하기.md

# %%
# --- Prompt ---
※ 프롬프트 작성 예시
  ① 자료의 최신성 확보 관련 문구  
     - 반드시 최신 정보를 찾아야 합니다.  
     - 오늘은 [2026.2.4] 입니다. 최근 일주일간 Google 검색으로 자료를 수집합니다. 

  ② 자료의 정확성 확보
     - 보고서는 객관적인 데이터와 발표자료를 근거로 출력해주세요. 
     - 상상이나 예시를 포함하지 말고, 실제 존재하는 사실만 나열하세요. 
     - 모든 수치나 인용문은 실제 존재하는 자료에 기반해야 하며, 가상의 인용은 절대 금지합니다.

# %%
# --- Prompt ---
※ 오류 수정 프롬프트 예시 (#1) 
작성된 보고서의 코스피 지수에 오류가 있습니다. 오늘([YYYY-MM-DD])의 실제 코스피 마감 지수는 [XXXX] 포인트입니다. 
위에서 입력한 실제 지수 데이터로 보고서를 수정해주세요.

※ 오류 수정 프롬프트 예시 (#2) 
보고서에 언급된 코스피 지수가 현재 시점의 데이터와 일치하지 않습니다. 
1. 검색 도구(Web Browsing)를 사용하여 오늘자 코스피 마감 지수와 등락률을 다시 검색하고 팩트 체크를 수행하세요.
2. 검증된 최신 데이터를 반영하여 보고서 전체를 처음부터 다시 생성해주세요. (출처를 반드시 명기할 것)

# %%
# --- Prompt ---

<br> 

#### 국내시장 마감시황 분석 

증권사 시황 애널리스트의 하루는 새벽부터 장 마감까지 숨 가쁘게 돌아갑니다. 이른 아침 글로벌 증시 분석을 시작으로, 장중 실시간으로 변동하는 시장 흐름과 뉴스를 끊임없이 모니터링해야 비로소 한 장의 보고서가 완성됩니다.

이제 LLM과의 대화를 통해, 고도의 집중력과 시간이 요구되는 마감시황 보고서를 전문가 수준으로 구현해 보겠습니다.

마감시황 보고서는 **자료의 최신성 확보**가 필요충분 조건입니다. 프롬프트에서는 오늘의 날짜를 명시하고, 구글 검색을 통해 데이터를 수집하도록 지시하였습니다. 

※ 프롬프트

# %%
# --- Prompt ---
# 지시문 
- 당신은 증권사의 리서치 연구원입니다. 
- 오늘의 국내주식시장 마감현황을 정리해서 보고서를 작성해야 합니다. 

# 제약 조건 
- 반드시 최신 정보를 찾아야 합니다.
- 오늘은 [2026.2.3] 입니다. Google 검색으로 자료를 수집합니다. 
- 보고서는 객관적인 데이터와 발표자료를 근거로 출력해주세요. 

# 출력형식 
- 오늘 거래소와 코스닥의 마감 데이터를 정리해주세요. : 지수 등락, 상승하락 종목수, 투자자별 매매동향 
- 대표적인 주식 시황 이슈를 3개 정리해주세요. 
- 주도주와 특징주 동향을 정리해주세요. 
- 투자자 유의사항을 제안해주세요.

# %%
# --- Prompt ---
※ 출력 결과 
![](https://static.wikidocs.net/images/page/286931/3.1.1_%EC%8B%9C%EC%9E%A5%EB%B6%84%EC%84%9D_01.png)
![](https://static.wikidocs.net/images/page/286931/3.1.1_%EC%8B%9C%EC%9E%A5%EB%B6%84%EC%84%9D_02.png)
![](https://static.wikidocs.net/images/page/286931/3.1.1_%EC%8B%9C%EC%9E%A5%EB%B6%84%EC%84%9D_03.png)
![](https://static.wikidocs.net/images/page/286931/3.1.1_%EC%8B%9C%EC%9E%A5%EB%B6%84%EC%84%9D_04.png)

<br> 

#### 국내시장 동향 분석

이제 시야를 넓혀 **주간(Weekly) 시장 분석 보고서**를 작성해 봅니다. 

단순히 등락률만 확인하는 것이 아니라, 국내외 증시의 흐름을 요약하고 지난 한 주를 관통했던 주도 섹터와 핵심 테마를 일목요연하게 정리합니다. 나아가 현재 시장이 어떤 국면인지 진단하는 평가 의견까지 도출하도록 지시합니다.

※ 프롬프트

# %%
# --- Prompt ---
# 지시문 
- 당신은 한국 경제 전문가이자 증권사 리서치 센터장입니다.
- 최근 주식시장의 이슈와 트렌드를 정리한 보고서를 작성해주세요.

# 제약 조건 
- 반드시 최신 정보를 찾아야 합니다.
- 오늘은 [2026.2.3] 입니다. 최근 일주일간 Google 검색으로 자료를 수집합니다. 
- 주식시장의 주요 이슈와 뉴스와 관련 자료를 수집해서 분석합니다.  
- 보고서는 객관적인 데이터와 발표자료를 근거로 출력해주세요. 

# 출력형식 
- 국내 및 해외지수 주가 흐름 요약
- 주도주 섹터, 주도주 종목  
- 주목할 테마와 이슈 
- 시장 국면 판단 : [상승 추세/하락 추세/박스권/변동성 확대] 
- 투자자 유의사항

# %%
# --- Prompt ---

※ 출력 결과
![](https://static.wikidocs.net/images/page/286931/3.1.1_%EC%8B%9C%EC%9E%A5%EB%B6%84%EC%84%9D_%EA%B5%AD%EB%82%B4%EC%8B%9C%EC%9E%A5%EB%8F%99%ED%96%A5%EB%B6%84%EC%84%9D_1.png)
![](https://static.wikidocs.net/images/page/286931/3.1.1_%EC%8B%9C%EC%9E%A5%EB%B6%84%EC%84%9D_%EA%B5%AD%EB%82%B4%EC%8B%9C%EC%9E%A5%EB%8F%99%ED%96%A5%EB%B6%84%EC%84%9D_2.png)
![](https://static.wikidocs.net/images/page/286931/3.1.1_%EC%8B%9C%EC%9E%A5%EB%B6%84%EC%84%9D_%EA%B5%AD%EB%82%B4%EC%8B%9C%EC%9E%A5%EB%8F%99%ED%96%A5%EB%B6%84%EC%84%9D_3.png)
![](https://static.wikidocs.net/images/page/286931/3.1.1_%EC%8B%9C%EC%9E%A5%EB%B6%84%EC%84%9D_%EA%B5%AD%EB%82%B4%EC%8B%9C%EC%9E%A5%EB%8F%99%ED%96%A5%EB%B6%84%EC%84%9D_4.png)

<br> 


#### 국내시장 이슈 분석 

이번에는 국내 주식시장에 큰 영향을 미치는 주요 이벤트를 선정하여 입체적인 분석 보고서를 작성해 봅니다.

예시 프롬프트는 정부의 주식시장 활성화 대책이 시장에 미칠 파급력을 진단하고, 이를 통해 실질적인 수혜가 예상되는 유망 업종과 종목을 도출하도록 설계되었습니다.

프롬프트 내에 '2025년 6월 이후 발표된 자료만 참고하라"는 명확한 시점 제한을 두었다는 점에 주목하기 바랍니다. 이는 LLM이 과거 데이터와 최신 정책을 혼동하지 않고, 최근의 시장 흐름을 반영하도록 강제하는 중요한 기법입니다.

※ 프롬프트

# %%
# --- Prompt ---
# 지시문 
- 당신은 한국 경제 전문가이자 증권사 리서치 센터장입니다.
- 정부의 주식시장 활성화 대책에 대하여, 주식시장에 미치는 영향과 투자유망 업종에 관한 보고서를 작성해주세요. 

# 제약 조건 
- 정부의 주식시장 활성화 대책은 2025년 6월 이후로 발표된 정보를 찾아야 합니다.
- 보고서는 객관적인 데이터와 발표자료를 근거로 출력해주세요. 
- 모든 수치나 인용문은 실제 존재하는 자료에 기반해야 하며, 가상의 인용은 절대 금지합니다.

# 출력형식 
- 대표적인 정부의 주식시장 활성화 대책과 주식시장에 미칠 영향력 평가 
- 주식시장 활성화 대책별 투자유망 업종 및 수혜주 출력 
- 투자자 유의사항

# %%
# --- Prompt ---

※ 출력 결과 
![](https://static.wikidocs.net/images/page/286931/3.1.1_%EC%8B%9C%EC%9E%A5%EB%B6%84%EC%84%9D_%EA%B5%AD%EB%82%B4%EC%8B%9C%EC%9E%A5%EC%9D%B4%EC%8A%88%EB%B6%84%EC%84%9D_1.png)
![](https://static.wikidocs.net/images/page/286931/3.1.1_%EC%8B%9C%EC%9E%A5%EB%B6%84%EC%84%9D_%EA%B5%AD%EB%82%B4%EC%8B%9C%EC%9E%A5%EC%9D%B4%EC%8A%88%EB%B6%84%EC%84%9D_2.png)
![](https://static.wikidocs.net/images/page/286931/3.1.1_%EC%8B%9C%EC%9E%A5%EB%B6%84%EC%84%9D_%EA%B5%AD%EB%82%B4%EC%8B%9C%EC%9E%A5%EC%9D%B4%EC%8A%88%EB%B6%84%EC%84%9D_3.png)


<br> 

#### 미국시장 마감시황 분석 

미국주식 시장은 한국시각으로 11시 30분(서머타임 기간은 10시 30분)에 시작하여 6시에 마감합니다. 이른 아침 LLM을 활용하여 밤새 있었던 시장 흐름을 정리한 고품질의 마감 보고서를 손쉽게 받아볼 수 있습니다.

프롬프트에서는 시차로 인한 혼동을 막기 위해 분석 대상 날짜를 정확히 기재하였습니다. 또한, 데이터의 정확도를 위해 월스트리트저널(WSJ), 블룸버그, 야후 파이낸스 등 신뢰도 높은 전문 사이트를 검색 대상으로 한정하였습니다. 

※ 프롬프트

# %%
# --- Prompt ---
# 지시문
- 당신은 글로벌 투자 전문가이자 증권사 리서치 센터장입니다.
- 글로벌 주식시장의 시황과, 이슈 트렌드를 정리한 보고서를 작성해주세요.

# 제약 조건
- 반드시 최신 정보를 찾아야 합니다.
- 미국시각으로 오늘은 [2026.2.2] 입니다.
- 주식시장의 주요 이슈와 뉴스와 관련 자료를 실시간으로 검색해서 분석합니다.
- Google 검색 도구를 사용하여 가장 최신 데이터를 가져옵니다. 
- 보고서는 객관적인 데이터와 발표자료를 근거로 출력해주세요.

# 정보 수집 사이트
- 월스트리트저널 : https://www.wsj.com/
- 블룸버그 : https://www.bloomberg.com
- 야후 파이낸스 : https://finance.yahoo.com/
- 뉴욕타임즈 : https://www.nytimes.com/section/business

# 출력형식
- 미국과 유럽, 아시아의 주요 증시 종가 요약
- 주도주 섹터, 주도주 종목
- 주목할 테마와 이슈
- 향후 미래 주가에 영향력이 큰 중요 뉴스 5개 요약
- 가장 많이 언급된 주가 종목과 관련 뉴스 5개 요약
- 시장 국면 판단 : [상승 추세/하락 추세/박스권/변동성 확대]
- 투자자 유의사항

# %%
# --- Prompt ---
![](https://static.wikidocs.net/images/page/286931/3.1.1_%EC%8B%9C%EC%9E%A5%EB%B6%84%EC%84%9D_%EB%AF%B8%EA%B5%AD%EC%8B%9C%EC%9E%A5%EB%A7%88%EA%B0%90_1.png)
![](https://static.wikidocs.net/images/page/286931/3.1.1_%EC%8B%9C%EC%9E%A5%EB%B6%84%EC%84%9D_%EB%AF%B8%EA%B5%AD%EC%8B%9C%EC%9E%A5%EB%A7%88%EA%B0%90_2.png)
![](https://static.wikidocs.net/images/page/286931/3.1.1_%EC%8B%9C%EC%9E%A5%EB%B6%84%EC%84%9D_%EB%AF%B8%EA%B5%AD%EC%8B%9C%EC%9E%A5%EB%A7%88%EA%B0%90_3.png)
![](https://static.wikidocs.net/images/page/286931/3.1.1_%EC%8B%9C%EC%9E%A5%EB%B6%84%EC%84%9D_%EB%AF%B8%EA%B5%AD%EC%8B%9C%EC%9E%A5%EB%A7%88%EA%B0%90_4.png)
![](https://static.wikidocs.net/images/page/286931/3.1.1_%EC%8B%9C%EC%9E%A5%EB%B6%84%EC%84%9D_%EB%AF%B8%EA%B5%AD%EC%8B%9C%EC%9E%A5%EB%A7%88%EA%B0%90_5.png)

<br> 

#### 미국시장 동향 분석

글로벌 리서치 센터장의 관점에서 최근 일주일간의 미국 증시 흐름과 핵심 트렌드를 심층 분석하여 보고서를 생성하도록 하였습니다. 주요 지수와 주도 섹터 분석과 함께 현재 시장의 국면을 진단하고 투자 유의사항까지 도출하도록 합니다. 

※ 프롬프트

# %%
# --- Prompt ---
# 지시문 
- 당신은 글로벌 투자 전문가이자 증권사 리서치 센터장입니다.
- 최근 미국 주식시장의 이슈와 트렌드를 정리한 보고서를 작성해주세요.

# 제약 조건 
- 반드시 최신 정보를 찾아야 합니다.
- 미국시각으로 오늘은 [2026.2.4] 입니다. 최근 일주일간 Google 검색으로 자료를 수집합니다. 
- 주식시장의 주요 이슈와 뉴스 및 관련 자료를 수집해서 분석합니다.  
- 보고서는 객관적인 데이터와 발표자료를 근거로 출력해주세요. 

# 정보 수집 참조 사이트 
- 월스트리트저널 : https://www.wsj.com/
- 블룸버그 : https://www.bloomberg.com
- 야후 파이낸스 : https://finance.yahoo.com/
- 뉴욕타임즈 : https://www.nytimes.com/ 

# 출력형식 
- 미국 주요 주가 흐름 요약 : 다우지수, 나스닥, S&P500 
- 주도주 섹터, 주도주 종목  
- 주목할 테마와 이슈 
- 시장 국면 판단 : [상승 추세/하락 추세/박스권/변동성 확대] 
- 투자자 유의사항

# %%
# --- Prompt ---

※ 출력 결과
![](https://static.wikidocs.net/images/page/286931/3.1.1_%EC%8B%9C%EC%9E%A5%EB%B6%84%EC%84%9D_%EB%AF%B8%EA%B5%AD%EC%8B%9C%EC%9E%A5%EB%8F%99%ED%96%A5%EB%B6%84%EC%84%9D_1.png)
![](https://static.wikidocs.net/images/page/286931/3.1.1_%EC%8B%9C%EC%9E%A5%EB%B6%84%EC%84%9D_%EB%AF%B8%EA%B5%AD%EC%8B%9C%EC%9E%A5%EB%8F%99%ED%96%A5%EB%B6%84%EC%84%9D_2.png)
![](https://static.wikidocs.net/images/page/286931/3.1.1_%EC%8B%9C%EC%9E%A5%EB%B6%84%EC%84%9D_%EB%AF%B8%EA%B5%AD%EC%8B%9C%EC%9E%A5%EB%8F%99%ED%96%A5%EB%B6%84%EC%84%9D_3.png)
![](https://static.wikidocs.net/images/page/286931/3.1.1_%EC%8B%9C%EC%9E%A5%EB%B6%84%EC%84%9D_%EB%AF%B8%EA%B5%AD%EC%8B%9C%EC%9E%A5%EB%8F%99%ED%96%A5%EB%B6%84%EC%84%9D_4.png)

<br> 


#### 미국시장 이슈 분석 

미국 시장의 주요 이벤트를 선정하여 입체적인 분석을 시도합니다.

예시 프롬프트는 향후 미국 기준금리 전망을 3가지 시나리오(공격적 인하, 점진적 인하, 동결 등)로 가정하고, 현재의 경제 지표를 근거로 각 시나리오의 **실현 확률을 예측** 하도록 설계하였습니다. 

또한 개별 시나리오에 따라 수혜가 예상되는 유망 섹터와 종목을 각각 도출합니다. 

※ 프롬프트

# %%
# --- Prompt ---
# 지시문 
- 당신은 글로벌 투자 전문가이자 증권사 리서치 센터장입니다.
- 미국의 기준금리 전망을 3가지 시나리오로 예측하고, 투자자 관점에서 시나리오별 대응전략 보고서를 작성해주세요.

# 제약 조건 
- 반드시 최신 정보를 찾아야 합니다.
- 미국시각으로 오늘은 [2026.2.4] 입니다. Google 검색으로 자료를 수집합니다. 
- 미국 금융시장의 주요 이슈와 뉴스 및 관련 자료를 수집해서 분석합니다.  
- 시나리오는 3가지로 가정 합니다. : 1.급격한 금리 인하 2.점진적 금리 인하 3.금리 동결 또는 인상
- 보고서는 객관적인 데이터와 발표자료를 근거로 출력해주세요. 

# 정보 수집 참조 사이트 
- 월스트리트저널 : https://www.wsj.com/
- 블룸버그 : https://www.bloomberg.com
- 야후 파이낸스 : https://finance.yahoo.com/
- 뉴욕타임즈 : https://www.nytimes.com/ 

# 출력형식 
- 시나리오별 실현 가능성 예측 : 전망, 근거, 확률(퍼센트로 표기) 
- 시나리오별 투자 전략 : 주식시장에 미치는 영향, 투자 유망 섹터, 투자 유망 종목  
- 투자자 유의사항

# %%
# --- Prompt ---

※ 출력 결과 
![](https://static.wikidocs.net/images/page/286931/3.1.1_%EC%8B%9C%EC%9E%A5%EB%B6%84%EC%84%9D_%EB%AF%B8%EA%B5%AD%EC%8B%9C%EC%9E%A5%EC%9D%B4%EC%8A%88%EB%B6%84%EC%84%9D_1.png)
![](https://static.wikidocs.net/images/page/286931/3.1.1_%EC%8B%9C%EC%9E%A5%EB%B6%84%EC%84%9D_%EB%AF%B8%EA%B5%AD%EC%8B%9C%EC%9E%A5%EC%9D%B4%EC%8A%88%EB%B6%84%EC%84%9D_2.png)
![](https://static.wikidocs.net/images/page/286931/3.1.1_%EC%8B%9C%EC%9E%A5%EB%B6%84%EC%84%9D_%EB%AF%B8%EA%B5%AD%EC%8B%9C%EC%9E%A5%EC%9D%B4%EC%8A%88%EB%B6%84%EC%84%9D_3.png)

<br> 


#### 글로벌 분산투자 보고서 : 국가 분산

이번에는 글로벌 분산 투자 관점에서 LLM의 제안을 활용해 봅니다. 분석 대상은 미국, 중국, 한국 등 3개 국가로 한정하였으며, 각 국가별 투자 비중과 논리적 근거를 생성합니다.

프롬프트 설계 시 투자 기간을 3년으로 명시하여, LLM이 단기적 변동성보다는 중기 투자 사이클에 최적화된 포트폴리오를 제시하도록 유도하였습니다.

※ 프롬프트

# %%
# --- Prompt ---
# 지시문 
- 당신은 글로벌 주식투자 전문가이자 증권사 리서치 센터장입니다.
- 미국과 중국, 한국 주식에 대한 투자전망과 분산투자와 관련한 보고서를 작성해주세요. 

# 제약 조건 
- 국가별 시황과 투자전망은 반드시 최신 정보를 찾아야 합니다.
- 오늘은 [2026.2.4] 입니다. 최근 자료는 Google 검색으로 수집합니다. 
- 국가별 분산투자는 3년 중기투자를 가정합니다.  
- 보고서는 객관적인 데이터와 발표자료를 근거로 출력해주세요. 
- 모든 수치나 인용문은 실제 존재하는 자료에 기반해야 하며, 가상의 인용은 절대 금지합니다.

# 출력형식 
- 미국, 중국, 한국의 올해 주가지수 흐름 요약
- 국가별로 투자시 점검해야할 사항 
- 국가별 분산투자 비중과 근거, 대표 주식 출력

# %%
# --- Prompt ---
# 지시문 
- 당신은 증권사 고객자산을 관리하고 있는 PB입니다.
- 연금 자산을 주식과 채권으로 분산투자하고자 하는 고객에 대하여 제안서를 만들어주세요.

# 제약 조건 
- 분산투자는 다음 분류로 수행합니다. 국내주식, 미국주식, 중국주식, 채권
- 오늘은 [2026.2.4] 입니다. 최근 자료는 Google 검색으로 수집합니다. 
- 분산투자는 3년 중기투자를 가정합니다.  
- 보고서는 객관적인 데이터와 발표자료를 근거로 출력해주세요. 
- 모든 수치나 인용문은 실제 존재하는 자료에 기반해야 하며, 가상의 인용은 절대 금지합니다.

# 출력형식 
- 미국, 중국, 한국의 최근 주가지수 흐름 요약
- 채권 시장 동향 
- 분산투자 비중과 근거 출력
- 투자자 유의사항

# %%
# --- Prompt ---

※ 출력결과 
![](https://static.wikidocs.net/images/page/286931/3.1.1_%EC%8B%9C%EC%9E%A5%EB%B6%84%EC%84%9D_a1_%EC%9E%90%EC%82%B0%EB%B0%B0%EB%B6%84_1.png)
![](https://static.wikidocs.net/images/page/286931/3.1.1_%EC%8B%9C%EC%9E%A5%EB%B6%84%EC%84%9D_a1_%EC%9E%90%EC%82%B0%EB%B0%B0%EB%B6%84_2.png)
![](https://static.wikidocs.net/images/page/286931/3.1.1_%EC%8B%9C%EC%9E%A5%EB%B6%84%EC%84%9D_a1_%EC%9E%90%EC%82%B0%EB%B0%B0%EB%B6%84_3.png)
![](https://static.wikidocs.net/images/page/286931/3.1.1_%EC%8B%9C%EC%9E%A5%EB%B6%84%EC%84%9D_a1_%EC%9E%90%EC%82%B0%EB%B0%B0%EB%B6%84_4.png)

<br> 

#### 유튜브 방송 요약  

최근 유튜브 플랫폼을 통해 양질의 주식 시장 분석 콘텐츠가 폭발적으로 공급되고 있습니다.

필자는 원본 영상을 직접 시청하는 것을 선호하지만, 현실적인 제약으로 인해 모든 콘텐츠를 소화하기엔 한계가 있습니다. 이때 LLM은 훌륭한 조력자가 됩니다. 간단한 프롬프트 입력만으로도 긴 영상의 방대한 내용을 일목요연하게 요약해주어, 정보 습득의 효율을 높여줄 수 있습니다.

※ 프롬프트

# %%
# --- Prompt ---
# 지시문 
다음 유튜브는 전일자 미국시장 마감시황 콘텐츠 입니다. 
출력형식에 맞추어 콘텐츠를 요약하고 투자정보를 제안해주세요. 
https://www.youtube.com/watch?v=vw8CfCn3j2U

# 출력형식 
- 투자자 관점의 방송의 핵심 내용 요약  
- 향후 미국시장과 한국 주식시장에 미칠 이슈 분석 
- 관련 수혜주 정리 : 미국주식, 국내주식 
- 투자자 유의사항

# %% [markdown]
# ### 3 1 2 종목 분석하기 (국내주식 해외주식).md

# %%
# --- Prompt ---
# 지시문 
- 당신은 증권사에서 조선업종을 담당하고 있는 리서치 연구원입니다. 
- 한화오션(종목번호 042660) 투자자를 대상으로, 투자전망 보고서를 작성해주세요. 

# 제약 조건 
- 한화오션(종목번호 042660)과 관련된 뉴스, 리서치보고서, 재무데이터를 수집해서 분석합니다.  
- 반드시 최신 정보를 찾아야 합니다.
- 오늘은 [2026.2.4] 입니다. Google 검색으로 자료를 수집합니다. 
- 보고서는 객관적인 데이터와 발표자료를 근거로 출력해주세요. 

# 출력형식 
- 한화오션(종목번호 042660)의 주가 추이와 실적을 요약합니다. 
- 한화오션(종목번호 042660) 투자와 관련된 이슈를 정리하고, 향후 실적과 주가에 미칠 영향을 나열합니다. 
- 목표주가를 제안하고, 근거를 제시합니다.  
- 투자자 유의사항을 제시합니다.

# %%
# --- Prompt ---

※ 출력 결과 
![](https://static.wikidocs.net/images/page/295154/3.1.2_%EC%A2%85%EB%AA%A9%EB%B6%84%EC%84%9D_01_%ED%95%9C%ED%99%94%EC%98%A4%EC%85%98_1.png)
![](https://static.wikidocs.net/images/page/295154/3.1.2_%EC%A2%85%EB%AA%A9%EB%B6%84%EC%84%9D_01_%ED%95%9C%ED%99%94%EC%98%A4%EC%85%98_2.png)
![](https://static.wikidocs.net/images/page/295154/3.1.2_%EC%A2%85%EB%AA%A9%EB%B6%84%EC%84%9D_01_%ED%95%9C%ED%99%94%EC%98%A4%EC%85%98_3.png)
![](https://static.wikidocs.net/images/page/295154/3.1.2_%EC%A2%85%EB%AA%A9%EB%B6%84%EC%84%9D_01_%ED%95%9C%ED%99%94%EC%98%A4%EC%85%98_4.png)

※ 참고 
생성된 보고서에서 해당 종목의 종가를 실제 주가와 확인하세요. 간혹 할루시네이션이 발생하는 경우 종목 종가를 다르게 제시하기도 합니다. 이때 아래와 같이 프롬프트를 작성하여 보고서 재생성을 지시합니다.

# %%
# --- Prompt ---
한화오션의 현재 주가는 144,300원입니다. 주가 데이터를 다시 검증해서 보고서를 작성해주세요.

# %%
# --- Prompt ---

<br>


#### 국내주식 종목 비교분석

이번에는 단일 기업 분석을 넘어, 경쟁 관계에 있는 두 종목을 심층적으로 비교하는 **'종목 간 비교 분석**을 수행해 봅니다.

예제에서는 실전 투자에서 빈번하게 마주하는 '양자택일'의 상황을 가정하여, 국내 반도체 대표주인 삼성전자와 SK하이닉스를 대상으로 LLM의 판단을 구해봅니다.

프롬프트는 두 기업의 주가 추이, 실적, 주요 이슈를 정밀하게 비교한 후 투자 전망 관점에서 우위에 있는 단 하나의 종목(Top Pick)을 최종 선정하도록 설계하였습니다. 

※ 프롬프트

# %%
# --- Prompt ---
# 지시문 
- 당신은 증권사에서 반도체 업종을 담당하고 있는 리서치 연구원입니다.
- 삼성전자와 SK하이닉스 주식 투자자를 대상으로, 두 주식의 투자전망을 비교하는 보고서를 작성해주세요. 

# 제약 조건 
- 삼성전자와 SK하이닉스와 관련된 뉴스, 리서치보고서, 재무데이터를 수집해서 분석합니다.  
- 반드시 최신 정보를 찾아야 합니다.
- 오늘은 [2026.2.9] 입니다. Google 검색으로 자료를 수집합니다. 
- 보고서는 객관적인 데이터와 발표자료를 근거로 출력해주세요. 
- 보고서는 삼성전자와 SK하이닉스의 향후 주가 전망을 비교하는 이슈에 집중합니다. 

# 출력형식 
- 최근의 삼성전자와 SK하이닉스의 주가 추이와 실적을 요약합니다. 
- 삼성전자와 SK하이닉스의 주요 이슈를 정리하고, 향후 실적과 주가에 미칠 영향에 대한 분석 결과를 나열합니다. 
- 현재 삼성전자와 SK하이닉스의 주가를 나열하고, 목표주가를 제안합니다. 
- 최종적으로 투자전망 측면에서 1개 기업을 선정하고, 선정 사유와 유의사항을 출력합니다.

# %%
# --- Prompt ---

※ 출력 결과 
![](https://static.wikidocs.net/images/page/295154/3.1.2_%EC%A2%85%EB%AA%A9%EB%B6%84%EC%84%9D_02_%EC%82%BC%EC%84%B1%ED%95%98%EB%8B%89_1.png)
![](https://static.wikidocs.net/images/page/295154/3.1.2_%EC%A2%85%EB%AA%A9%EB%B6%84%EC%84%9D_02_%EC%82%BC%EC%84%B1%ED%95%98%EB%8B%89_2.png)
![](https://static.wikidocs.net/images/page/295154/3.1.2_%EC%A2%85%EB%AA%A9%EB%B6%84%EC%84%9D_02_%EC%82%BC%EC%84%B1%ED%95%98%EB%8B%89_3.png)
![](https://static.wikidocs.net/images/page/295154/3.1.2_%EC%A2%85%EB%AA%A9%EB%B6%84%EC%84%9D_02_%EC%82%BC%EC%84%B1%ED%95%98%EB%8B%89_4.png)

<br> 

#### 국내주식 종목추천 : 반도체 섹터 

이번에는 LLM을 활용하여 특정 산업군을 심층 진단하는 **섹터(Sector) 분석 기반 종목 추천 보고서**를 작성합니다.

실습 예제는 반도체 섹터로 삼성전자와 SK하이닉스의 밸류체인에서 견고한 공급망을 확보한 유망 기업, 즉 낙수 효과가 기대되는 소부장(소재·부품·장비) 종목을 발굴하는 구체적인 시나리오를 적용했습니다.

※ 프롬프트

# %%
# --- Prompt ---
# 지시문 
- 당신은 증권사에서 반도체 업종을 담당하고 있는 리서치 연구원입니다.
- 반도체 업종에서 삼성전자 및 SK하이닉스와의 공급망 분석에 기반하여 투자유망 종목을 추천해주세요. 

# 제약 조건 
- 삼성전자와 SK하이닉스를 포함하여 반도체 업종의 기업과 관련된 뉴스, 리서치보고서, 재무데이터를 수집해서 분석합니다.  
- 반드시 최신 정보를 찾아야 합니다.
- 오늘은 [2026.2.9] 입니다. Google 검색으로 자료를 수집합니다. 
- 보고서는 객관적인 데이터와 발표자료를 근거로 출력해주세요. 

# 출력형식 
- 삼성전자와 SK하이닉스의 공급사 중에서, 가장 큰 수혜가 예상되는 주식을 3개 선정합니다.
- 선정된 주식별로 기업개요, 주요 이슈를 정리합니다. 
- 선정된 기업별로 현재 주가와 향후 목표주가를 제안합니다. 
- 최종적으로 투자전망 측면에서 1개 기업을 선정하고, 선정 사유와 유의사항을 출력합니다.

# %%
# --- Prompt ---

※ 출력 결과 
![](https://static.wikidocs.net/images/page/295154/3.1.2_%EC%A2%85%EB%AA%A9%EB%B6%84%EC%84%9D_03_%EB%B0%98%EB%8F%84%EC%B2%B4_1.png)
![](https://static.wikidocs.net/images/page/295154/3.1.2_%EC%A2%85%EB%AA%A9%EB%B6%84%EC%84%9D_03_%EB%B0%98%EB%8F%84%EC%B2%B4_2.png)
![](https://static.wikidocs.net/images/page/295154/3.1.2_%EC%A2%85%EB%AA%A9%EB%B6%84%EC%84%9D_03_%EB%B0%98%EB%8F%84%EC%B2%B4_3.png)
![](https://static.wikidocs.net/images/page/295154/3.1.2_%EC%A2%85%EB%AA%A9%EB%B6%84%EC%84%9D_03_%EB%B0%98%EB%8F%84%EC%B2%B4_4.png)

<br> 

#### 국내주식 종목추천 : 고객성향별(적극투자형/안정추구형) 

이번에는 고객의 **리스크 성향**에 최적화된 맞춤형 종목 추천 보고서를 생성합니다.

증권사에서는 설문을 통해 고객의 재무 상태, 투자 경험, 목적 및 기간, 손실 감내도 등을 종합적으로 평가하고, 이를 기반으로 투자자를 5단계(안정형~공격투자형)로 세분화합니다.

본 예제에서는 **적극투자형**과 **안정추구형**이라는 두 가지 대표 유형으로 단순화하였습니다. 이를 통해 각 성향의 니즈에 부합하는 국내 주식 포트폴리오를 도출하는 과정을 실습합니다.

※ 프롬프트

# %%
# --- Prompt ---
# 지시문 
- 당신은 증권사에서 고객자산관리를 담당하고 있는 PB입니다. 
- 고객의 투자위험 성향에 따라 국내주식 투자 포트폴리오를 작성해주세요. 
- 고객의 투자위험 성향은 <적극투자형>과 <안정추구형>으로 구분합니다. 

# 고객의 투자위험 감수 수준 설명  
- 안정추구형 : 이자 소득 이상의 안정적인 수익 추구 
- 적극투자형 : 시장 평균 수익률을 초과하는 높은 수익 추구 

# 제약 조건 
- 반드시 최신 정보를 찾아야 합니다.
- 오늘은 [2026.2.9] 입니다. Google 검색으로 자료를 수집합니다. 
- 보고서는 객관적인 데이터와 발표자료를 근거로 출력해주세요. 

# 출력형식 
- 국내주식 시장 전망과 이슈 및 트렌드 정리 
- 안정추구형 고객 대상 국내주식 3개 종목 추천 : 선정사유, 현재가, 목표주가, 기대수익률, 유의사항
- 적극투자형 고객 대상 국내주식 3개 종목 추천 : 선정사유, 현재가, 목표주가, 기대수익률, 유의사항

# %%
# --- Prompt ---
![](https://static.wikidocs.net/images/page/295154/3.1.2_%EC%A2%85%EB%AA%A9%EB%B6%84%EC%84%9D_04_%EA%B5%AD%EB%82%B4%EC%A3%BC%EC%8B%9D%EC%B6%94%EC%B2%9C_1.png)
![](https://static.wikidocs.net/images/page/295154/3.1.2_%EC%A2%85%EB%AA%A9%EB%B6%84%EC%84%9D_04_%EA%B5%AD%EB%82%B4%EC%A3%BC%EC%8B%9D%EC%B6%94%EC%B2%9C_2.png)
![](https://static.wikidocs.net/images/page/295154/3.1.2_%EC%A2%85%EB%AA%A9%EB%B6%84%EC%84%9D_04_%EA%B5%AD%EB%82%B4%EC%A3%BC%EC%8B%9D%EC%B6%94%EC%B2%9C_3.png)
![](https://static.wikidocs.net/images/page/295154/3.1.2_%EC%A2%85%EB%AA%A9%EB%B6%84%EC%84%9D_04_%EA%B5%AD%EB%82%B4%EC%A3%BC%EC%8B%9D%EC%B6%94%EC%B2%9C_4.png)

<br> 

#### 국내주식 종목추천 : 멀티팩터 

필자가 가장 선호하는 투자 전략인 **멀티팩터 기반의 탑다운 접근법**을 소개합니다. 3가지 멀티팩터(모멘텀·밸류·퀄리티)를 활용해 유망 업종을 먼저 선별하고, 해당 업종 내에서 우량 종목을 발굴하는 하향식 분석 방식입니다.

실습 예제에서는 LLM을 활용하여 상위 3개 유망 섹터를 도출하고, 이어 각 섹터별 추천 종목과 그 선정 근거를 제시합니다.

분석 결과의 정합성을 높이기 위해서는 LLM이 각 팩터의 개념을 필자의 의도대로 정확히 이해하는 것이 필수적입니다. 따라서 프롬프트에 각 멀티팩터 지표의 상세 정의와 평가 기준을 별도의 가이드라인으로 명시하였습니다.

※ 프롬프트

# %%
# --- Prompt ---
# 지시문 
- 당신은 한국 경제 전문가이자 퀀트 투자 전략가입니다.
- 주식시장의 이슈와 트렌드를 분석하여, 향후 투자 전망이 우수한 섹터와 종목을 추천해주세요. 
- 종목 추출은 멀티팩터 모델 기법을 적용해주세요. 

# 제약 조건 
- 최근의 국내 경제, 금융, 주식시장의 주요 이슈와 뉴스를 수집해서 분석합니다.  
- 오늘은 [2026.2.9] 입니다. Google 검색으로 자료를 수집합니다. 
- 앞으로 3개월간 주가 상승률이 가장 높을 것으로 예상되는 3개 섹터를 추출 합니다. 
- 추출된 섹터에 포함되는 종목 중에서, 가장 주가 상승률이 높을 것으로 예상되는 종목을 3개를 추출 합니다. 
- 유망 섹터와 종목을 추출할때에는 멀티팩터 지표인 모멘텀, 밸류, 퀄러티 지표를 고려하고 근거에 포함해주세요. 
- 멀티팩터 지표는 다음과 같이 7가지로 정의 합니다. 
  - 모멘텀 지표 : 주가, 거래량 
  - 밸류 지표 : PER, PBR
  - 퀄러티 지표 : 매출액 증가율, 영업이익 증가율, 순이익 증가율 
- 보고서는 객관적인 데이터와 발표자료를 근거로 출력해주세요. 

# 출력형식 
- 향후 3개월 간 투자 유망 섹터를 3개 나열하고, 근거를 제시 합니다.
- 3개 유망 섹터내에서 주가 상승률이 높을 것으로 예상되는 종목을 3개 나열하고, 근거를 제시합니다.

# %%
# --- Prompt ---

※ 출력 결과
![](https://static.wikidocs.net/images/page/295154/3.1.2_%EC%A2%85%EB%AA%A9%EB%B6%84%EC%84%9D_05_%EB%A9%80%ED%8B%B0%ED%8C%A9%ED%84%B0_1.png)
![](https://static.wikidocs.net/images/page/295154/3.1.2_%EC%A2%85%EB%AA%A9%EB%B6%84%EC%84%9D_05_%EB%A9%80%ED%8B%B0%ED%8C%A9%ED%84%B0_2.png)
![](https://static.wikidocs.net/images/page/295154/3.1.2_%EC%A2%85%EB%AA%A9%EB%B6%84%EC%84%9D_05_%EB%A9%80%ED%8B%B0%ED%8C%A9%ED%84%B0_3.png)
![](https://static.wikidocs.net/images/page/295154/3.1.2_%EC%A2%85%EB%AA%A9%EB%B6%84%EC%84%9D_05_%EB%A9%80%ED%8B%B0%ED%8C%A9%ED%84%B0_4.png)
![](https://static.wikidocs.net/images/page/295154/3.1.2_%EC%A2%85%EB%AA%A9%EB%B6%84%EC%84%9D_05_%EB%A9%80%ED%8B%B0%ED%8C%A9%ED%84%B0_5.png)

<br> 


#### 해외주식 종목분석

국내 주식 분석을 통해 검증된 LLM 프롬프트 방법론을 해외 주식 시장으로 확장 적용합니다.

해외 주식의 경우 언어 장벽과 파편화된 정보로 인해 개인 투자자가 상세 데이터를 확보하는 데 어려움이 있습니다. 하지만 정교하게 설계된 프롬프트를 활용하면 기업 개요, 실적 추이, 주가 흐름, 목표 주가 등 핵심 투자 정보를 일목요연한 보고서로 즉시 산출할 수 있습니다.

분석의 품질을 높이기 위해 프롬프트 작성 시 정확한 종목명과 종목코드를 명시하였습니다. 또한 정보의 출처를 월스트리트저널(WSJ), 블룸버그(Bloomberg), 야후 파이낸스(Yahoo Finance) 등 공신력 있는 글로벌 금융 미디어로 특정하여 결과물의 신뢰도를 확보하도록 하였습니다. 

※ 프롬프트

# %%
# --- Prompt ---
# 지시문 
- 당신은 증권사에서 미국주식 분석을 담당하고 있는 리서치 연구원입니다. 
- 로빈후드(심볼 HOOD) 투자자를 대상으로, 투자전망 보고서를 작성해주세요. 

# 제약 조건 
- 로빈후드(심볼 HOOD)와 관련된 뉴스, 리서치보고서, 재무데이터를 수집해서 분석합니다.  
- 반드시 최신 정보를 찾아야 합니다.
- 오늘은 [2026.2.9] 입니다. Google 검색으로 자료를 수집합니다. 
- 보고서는 객관적인 데이터와 발표자료를 근거로 출력해주세요. 

# 정보 수집 사이트
- 월스트리트저널 : https://www.wsj.com/
- 블룸버그 : https://www.bloomberg.com
- 야후 파이낸스 : https://finance.yahoo.com/
- 뉴욕타임즈 : https://www.nytimes.com/section/business

# 출력형식 
- 로빈후드(심볼 HOOD)의 주가 추이와 실적을 요약합니다. 
- 로빈후드(심볼 HOOD) 투자와 관련된 이슈를 정리하고, 향후 실적과 주가에 미칠 영향을 나열합니다. 
- 목표주가를 제안하고, 근거를 제시합니다.  
- 투자자 유의사항을 제시합니다.

# %%
# --- Prompt ---
# 지시문 
- 당신은 증권사에서 미국주식 분석을 담당하고 있는 리서치 연구원입니다. 
- 넷플릭스(심볼 NFLX)와 디즈니(심볼 DIS) 주식 투자자를 대상으로, 두 주식의 투자전망을 비교하는 보고서를 작성해주세요. 

# 제약 조건 
- 넷플릭스(심볼 NFLX)와 디즈니(심볼 DIS)와 관련된 뉴스, 리서치보고서, 재무데이터를 수집해서 분석합니다.  
- 반드시 최신 정보를 찾아야 합니다.
- 오늘은 [2026.2.9] 입니다. Google 검색으로 자료를 수집합니다. 
- 보고서는 객관적인 데이터와 발표자료를 근거로 출력해주세요. 
- 보고서는 넷플릭스(심볼 NFLX)와 디즈니(심볼 DIS)의 향후 주가 전망을 비교하는 이슈에 집중합니다. 

# 정보 수집 사이트
- 월스트리트저널 : https://www.wsj.com/
- 블룸버그 : https://www.bloomberg.com
- 야후 파이낸스 : https://finance.yahoo.com/
- 뉴욕타임즈 : https://www.nytimes.com/section/business

# 출력형식 
- 최근의 넷플릭스(심볼 NFLX)와 디즈니(심볼 DIS)의 주가 추이와 실적을 요약합니다. 
- 넷플릭스(심볼 NFLX)와 디즈니(심볼 DIS)의 주요 이슈를 정리하고, 향후 실적과 주가에 미칠 영향에 대한 분석 결과를 나열합니다. 
- 현재 넷플릭스(심볼 NFLX)와 디즈니(심볼 DIS)의 주가를 나열하고, 목표주가를 제안합니다. 
- 최종적으로 투자전망 측면에서 1개 기업을 선정하고, 선정 사유와 유의사항을 출력합니다.  
- 투자자 유의사항을 제시합니다.

# %%
# --- Prompt ---

※ 출력 결과
![](https://static.wikidocs.net/images/page/295154/3.1.2_%EC%A2%85%EB%AA%A9%EB%B6%84%EC%84%9D_07_%EB%84%B7%ED%94%8C%EB%94%94%EC%A6%88%EB%8B%88_1.png)
![](https://static.wikidocs.net/images/page/295154/3.1.2_%EC%A2%85%EB%AA%A9%EB%B6%84%EC%84%9D_07_%EB%84%B7%ED%94%8C%EB%94%94%EC%A6%88%EB%8B%88_2.png)
![](https://static.wikidocs.net/images/page/295154/3.1.2_%EC%A2%85%EB%AA%A9%EB%B6%84%EC%84%9D_07_%EB%84%B7%ED%94%8C%EB%94%94%EC%A6%88%EB%8B%88_3.png)
![](https://static.wikidocs.net/images/page/295154/3.1.2_%EC%A2%85%EB%AA%A9%EB%B6%84%EC%84%9D_07_%EB%84%B7%ED%94%8C%EB%94%94%EC%A6%88%EB%8B%88_4.png)
![](https://static.wikidocs.net/images/page/295154/3.1.2_%EC%A2%85%EB%AA%A9%EB%B6%84%EC%84%9D_07_%EB%84%B7%ED%94%8C%EB%94%94%EC%A6%88%EB%8B%88_5.png)

<br> 

#### 해외주식 종목추천 : 헬스케어 섹터 

LLM의 강력한 정보 처리 능력은 개인 투자자에게 진입 장벽이 높은 해외 특정 섹터를 분석할 때 더욱 빛을 발합니다.

예제에서는 전문 지식이 요구되는 글로벌 제약/바이오 산업을 분석 대상으로 삼았습니다. 해당 섹터 내에서 투자 매력도가 가장 높은 최선호주(Top Pick)를 선별하고, 선정 논리와 목표 주가, 리스크 요인(유의사항)을 포함한 종합 분석을 수행합니다.

프롬프트에 범용적인 기준이 아닌 신약 파이프라인이나 임상 결과 등 해당 섹터의 특성을 반영한 구체적인 선정 기준을 가이드라인으로 제시하여 보고서의 정합성과 품질을 극대화하였습니다.


※ 프롬프트

# %%
# --- Prompt ---
# 지시문 
- 당신은 증권사에서 글로벌 제약/바이오 업종을 담당하고 있는 리서치 연구원입니다.
- 글로벌 제약/바이오 업종에서 투자유망 종목을 추천해주세요. 

# 제약 조건 
- 반드시 최신 정보를 찾아야 합니다.
- 오늘은 [2026.2.9] 입니다. Google 검색으로 자료를 수집합니다. 
- 보고서는 객관적인 데이터와 발표자료를 근거로 출력해주세요. 
- 투자 유망 종목 선정은 다음의 기준을 참고합니다. 
  1. 기업의 핵심 제품/기술이 무엇인가?
  2. FDA/규제 리스크는 낮은가?
  3. 정치적/정책 변화에 대한 민감도는? 
  4. 재무 상태는 건전한가? 
  5. 장기적인 인구 통계학적 변화의 수혜를 받는가?

# 출력형식 
- 투자 전망 측면에서 가장 우수한 주식을 3개 선정합니다.
- 선정된 주식별로 선정 근거, 주가 추이와 목표가, 유의사항을 출력합니다. 
- 최종적으로 투자 전망 측면에서 1개 기업을 선정하고 선정 사유를 출력합니다.

# %%
# --- Prompt ---

※ 출력 결과
![](https://static.wikidocs.net/images/page/295154/3.1.2_%EC%A2%85%EB%AA%A9%EB%B6%84%EC%84%9D_08_%EB%AF%B8%EA%B5%AD%ED%97%AC%EC%8A%A4_1.png)
![](https://static.wikidocs.net/images/page/295154/3.1.2_%EC%A2%85%EB%AA%A9%EB%B6%84%EC%84%9D_08_%EB%AF%B8%EA%B5%AD%ED%97%AC%EC%8A%A4_2.png)
![](https://static.wikidocs.net/images/page/295154/3.1.2_%EC%A2%85%EB%AA%A9%EB%B6%84%EC%84%9D_08_%EB%AF%B8%EA%B5%AD%ED%97%AC%EC%8A%A4_3.png)
![](https://static.wikidocs.net/images/page/295154/3.1.2_%EC%A2%85%EB%AA%A9%EB%B6%84%EC%84%9D_08_%EB%AF%B8%EA%B5%AD%ED%97%AC%EC%8A%A4_4.png)

<br> 

#### 해외주식 종목추천 : 고객성향별(적극투자형/안정추구형) 

국내 주식에 적용했던 '리스크 성향별 맞춤 전략'을 미국 주식 시장으로 확장합니다.

예제에서는 투자자를 **적극투자형**과 **안정추구형**으로 분류하고, 각 성향에 최적화된 미국 주식 포트폴리오를 도출합니다. 

보고서에는 현재가와 목표주가를 함께 명시하여, 투자자가 기대 수익률을 직관적으로 파악하고 종목 간 매력도를 쉽게 비교할 수 있도록 설계했습니다.   

※ 프롬프트

# %%
# --- Prompt ---
# 지시문 
- 당신은 증권사에서 고객자산관리를 담당하고 있는 PB입니다. 
- 고객의 투자위험 성향에 따라 미국주식 투자 포트폴리오를 작성해주세요. 
- 고객의 투자위험 성향은 <적극투자형>과 <안정추구형>으로 구분합니다. 

# 고객의 투자위험 감수 수준 설명  
- 안정추구형 : 이자 소득 이상의 안정적인 수익 추구 
- 적극투자형 : 시장 평균 수익률을 초과하는 높은 수익 추구 

# 제약 조건 
- 반드시 최신 정보를 찾아야 합니다.
- 오늘은 [2026.2.9] 입니다. Google 검색으로 자료를 수집합니다. 
- 보고서는 객관적인 데이터와 발표자료를 근거로 출력해주세요. 

# 정보 수집 사이트
- 월스트리트저널 : https://www.wsj.com/
- 블룸버그 : https://www.bloomberg.com
- 야후 파이낸스 : https://finance.yahoo.com/
- 뉴욕타임즈 : https://www.nytimes.com/section/business

# 출력형식 
- 미국주식 시장 전망과 이슈 및 트렌드 정리 
- 안정추구형 고객 대상 미국주식 3개 종목 추천 : 선정사유, 현재가, 목표주가, 기대수익률, 유의사항
- 적극투자형 고객 대상 미국주식 3개 종목 추천 : 선정사유, 현재가, 목표주가, 기대수익률, 유의사항

# %%
# --- Prompt ---
# 지시문 
- 당신은 글로벌 경제 전문가이자 퀀트 투자 전략가입니다.
- 미국 주식시장의 이슈와 트렌드를 분석하여, 향후 투자 전망이 우수한 섹터와 종목을 추천해주세요. 
- 종목 추출은 멀티팩터 모델 기법을 적용해주세요. 

# 제약 조건 
- 최근의 미국의 경제, 금융, 주식시장의 주요 이슈와 뉴스를 수집해서 분석합니다.  
- 오늘은 [2025.11.29] 입니다. Google 검색으로 자료를 수집합니다. 
- 앞으로 3개월간 주가 상승률이 가장 높을 것으로 예상되는 3개 섹터를 추출 합니다. 
- 추출된 섹터에 포함되는 종목 중에서, 가장 주가 상승률이 높을 것으로 예상되는 종목을 3개를 추출 합니다. 
- 유망 섹터와 종목을 추출할때에는 멀티팩터 지표인 모멘텀, 밸류, 퀄러티 지표를 고려하고 근거에 포함해주세요. 
- 멀티팩터 지표는 다음과 같이 7가지로 정의 합니다. 
  - 모멘텀 지표 : 주가, 거래량 
  - 밸류 지표 : PER, PBR
  - 퀄러티 지표 : 매출액 증가율, 영업이익 증가율, 순이익 증가율 
- 보고서는 객관적인 데이터와 발표자료를 근거로 출력해주세요. 

# 정보 수집 사이트
- 월스트리트저널 : https://www.wsj.com/
- 블룸버그 : https://www.bloomberg.com
- 야후 파이낸스 : https://finance.yahoo.com/
- 뉴욕타임즈 : https://www.nytimes.com/section/business

# 출력형식 
- 향후 3개월 간 투자 유망 섹터를 3개 나열하고, 근거를 제시 합니다.
- 3개 유망 섹터내에서 주가 상승률이 높을 것으로 예상되는 종목을 3개 나열하고, 근거를 제시합니다.

# %%
# --- Prompt ---

※ 출력 결과 
![](https://static.wikidocs.net/images/page/295154/3.1.2_%EC%A2%85%EB%AA%A9%EB%B6%84%EC%84%9D_10_%EB%AF%B8%EA%B5%AD%EB%A9%80%ED%8B%B0%EB%A6%AC%EC%96%BC_1.png)
![](https://static.wikidocs.net/images/page/295154/3.1.2_%EC%A2%85%EB%AA%A9%EB%B6%84%EC%84%9D_10_%EB%AF%B8%EA%B5%AD%EB%A9%80%ED%8B%B0%EB%A6%AC%EC%96%BC_2.png)
![](https://static.wikidocs.net/images/page/295154/3.1.2_%EC%A2%85%EB%AA%A9%EB%B6%84%EC%84%9D_10_%EB%AF%B8%EA%B5%AD%EB%A9%80%ED%8B%B0%EB%A6%AC%EC%96%BC_3.png)
![](https://static.wikidocs.net/images/page/295154/3.1.2_%EC%A2%85%EB%AA%A9%EB%B6%84%EC%84%9D_10_%EB%AF%B8%EA%B5%AD%EB%A9%80%ED%8B%B0%EB%A6%AC%EC%96%BC_4.png)
![](https://static.wikidocs.net/images/page/295154/3.1.2_%EC%A2%85%EB%AA%A9%EB%B6%84%EC%84%9D_10_%EB%AF%B8%EA%B5%AD%EB%A9%80%ED%8B%B0%EB%A6%AC%EC%96%BC_5.png)

<br> 

#### 벤저민 그레이엄의 7가지 법칙

벤저민 그레이엄(1894~1976)은 감과 내부정보에 의존한 투기가 횡행하던 주식시장에 과학적 증권 분석의 기틀을 마련하여 **가치투자의 아버지**로 불립니다.

예제에서는 그의 역작 <현명한 투자자>에 수록된 **방어적 투자자를 위한 7가지 포트폴리오 불변의 법칙**을 LLM에 적용하여 심층 보고서를 생성합니다.

프롬프트에서는 그레이엄이 정의한 '방어적 투자자'의 개념에 맞춰 고객의 성향을 **안정추구형**으로 명확히 설정하였으며, 이를 통해 7가지 선별 기준을 통과한 종목들로만 구성된 포트폴리오를 도출하도록 하였습니다.

# %%
# --- Prompt ---
# 지시문 
- 당신은 증권사에서 고객자산관리를 담당하고 있는 PB입니다. 
- <안정추구형>고객을 대상으로 국내주식과 해외주식 포트폴리오를 구성하고자 합니다. 
- 고객은 안정적인 수익성과를 추구하고, 3년 이상의 중장기투자를 선호합니다. 
- 벤자민 그레이엄의 <방어적 투자자를 위한 7가지 종목 산정 방법>을 참고하여, 포트폴리오를 구성해주세요. 

# 방어적 투자자를 위한 7가지 종목 산정 방법
- 1. 규모의 적정성 
- 2. 충분히 건전한 재무 상태 
- 3. 연속 배당금 지급 
- 4. 연속 흑자 기조
- 5. 순이익 지속적 성장 기조 
- 6. 낮은 PER 수준 
- 7. 낮은 PBR 수준 

# 제약 조건 
- 반드시 최신 정보를 찾아야 합니다.
- 오늘은 [2026.2.9] 입니다. Google 검색으로 자료를 수집합니다. 
- 보고서는 객관적인 데이터와 발표자료를 근거로 출력해주세요. 

# 출력형식 
- 고객을 위한 <방어적 투자자를 위한 7가지 종목 산정 방법> 설명 
- <방어적 투자자를 위한 7가지 종목 산정 방법> 기준으로 국내주식 2개 종목 추천 : 선정사유, 투자포인트, 기대수익률, 유의사항
- <방어적 투자자를 위한 7가지 종목 산정 방법> 기준으로 해외주식 2개 종목 추천 : 선정사유, 투자포인트, 기대수익률, 유의사항

# %%
# --- Prompt ---

※ 출력 결과 
![](https://static.wikidocs.net/images/page/295154/3.1.2_%EC%A2%85%EB%AA%A9%EB%B6%84%EC%84%9D_11_%EB%B2%A4%EC%9E%90%EB%AF%BC_1.png)
![](https://static.wikidocs.net/images/page/295154/3.1.2_%EC%A2%85%EB%AA%A9%EB%B6%84%EC%84%9D_11_%EB%B2%A4%EC%9E%90%EB%AF%BC_2.png)
![](https://static.wikidocs.net/images/page/295154/3.1.2_%EC%A2%85%EB%AA%A9%EB%B6%84%EC%84%9D_11_%EB%B2%A4%EC%9E%90%EB%AF%BC_3.png)
![](https://static.wikidocs.net/images/page/295154/3.1.2_%EC%A2%85%EB%AA%A9%EB%B6%84%EC%84%9D_11_%EB%B2%A4%EC%9E%90%EB%AF%BC_4.png)
![](https://static.wikidocs.net/images/page/295154/3.1.2_%EC%A2%85%EB%AA%A9%EB%B6%84%EC%84%9D_11_%EB%B2%A4%EC%9E%90%EB%AF%BC_5.png)
![](https://static.wikidocs.net/images/page/295154/3.1.2_%EC%A2%85%EB%AA%A9%EB%B6%84%EC%84%9D_11_%EB%B2%A4%EC%9E%90%EB%AF%BC_6.png)


 <br>


#### 필립 피셔 15가지 법칙

워런 버핏의 정신적 스승이자 **성장주 투자의 아버지**로 불리는 필립 피셔의 투자 철학을 LLM에 적용해 봅니다.

벤저민 그레이엄이 재무제표에 기반한 정량적 분석과 가치주 투자의 원형을 정립했다면, 필립 피셔는 숫자 너머의 기업 경쟁력을 평가하는 **정성적 분석**에 방점을 두었습니다. 그의 저서 <위대한 기업에 투자하라>에 소개된 15가지 법칙은 크게 성장성, 수익성, 그리고 경영진의 자질이라는 세 가지 핵심 축으로 요약됩니다.

예제에서는 15가지 원칙을 프롬프트에 반영하여, 피셔의 기준에 부합하는 국내 및 해외 유망 종목 발굴 보고서를 생성합니다.

※ 프롬프트

# %%
# --- Prompt ---
# 지시문 
- 당신은 증권사에서 고객자산관리를 담당하고 있는 PB입니다. 
- <성장추구형>고객을 대상으로 국내주식과 해외주식 포트폴리오를 구성하고자 합니다. 
- 고객은 성장주 투자를 선호하고, 1년 이상의 중장기투자를 선호합니다. 
- 필립 피셔의 15가지 투자 원칙을 참고하여, 포트폴리오를 구성해주세요. 

# 필립 피셔의 15가지 투자 원칙
- 1. (성장잠재력) 시장 잠재력
- 2. (성장잠재력) 신제품 개발 의지 
- 3. (성장잠재력) R&D 효율성
- 4. (성장잠재력) 영업 조직
- 5. (수익효율성) 영업이익률
- 6. (수익효율성) 마진 유지 능력
- 7. (수익효율성) 원가 분석
- 8. (수익효율성) 업게 특수성, 경쟁우위
- 9. (경영진자질) 노사 관계 
- 10. (경영진자질) 임원 관계 
- 11. (경영진자질) 경영진의 깊이
- 12. (경영진자질) 장기적 관점 
- 13. (경영진자질) 증자 위험
- 14. (경영진자질) 솔직함
- 15. (경영진자질) 진실성 

# 제약 조건 
- 반드시 최신 정보를 찾아야 합니다.
- 오늘은 [2026.2.9] 입니다. Google 검색으로 자료를 수집합니다. 
- 종목 추천 시 <필립 피셔의 15가지 투자 원칙>을 요약해서 활용하고, 보고서에 선정근거를 제안합니다. 
- 보고서는 객관적인 데이터와 발표자료를 근거로 출력해주세요. 

# 출력형식 
- 고객을 위한 <필립 피셔의 15가지 투자 원칙> 요약 설명 
- <필립 피셔의 15가지 투자 원칙> 기준으로 국내주식 2개 종목 추천 : 선정사유, 투자포인트, 기대수익률, 유의사항
- <필립 피셔의 15가지 투자 원칙> 기준으로 해외주식 2개 종목 추천 : 선정사유, 투자포인트, 기대수익률, 유의사항

# %% [markdown]
# ### 3 1 3 ETF 분석하기.md

# %%
# --- Prompt ---
# 지시문 
- 당신은 증권사에서 ETF상품 리서치를 담당하는 연구원입니다.
- 증권사 영업점 직원을 대상으로 배포할 ETF상품 제안서를 작성해주세요. 
- 제안서는 영업점 직원이 ETF 투자고객 대상 상담용으로 활용할 예정입니다. 

# 제안서 작성 ETF
- KODEX AI전력핵심설비(종목코드 487240) 

# 제약 조건 
- 반드시 최신 정보를 찾아야 합니다.
- 오늘은 [2026.2.11] 입니다. Google 검색으로 자료를 수집합니다. 
- 보고서는 객관적인 데이터와 발표자료를 근거로 출력해주세요. 

# ETF 정보 참조 사이트 
- https://finance.naver.com/sise/etf.naver

# 출력형식 
- ETF 설명 : 투자포인트 3줄 핵심 요약, 기초지수, 구성자산(PDF), 총보수 수준, 순자산규모와 거래량 수준, 괴리율 및 추적오차, 분배금 지급 
- ETF 수익률 : 종목구성(1개월, 3개월, 6개월, 1년)
- ETF에 적합한 투자자 안내 (타겟고객)  
- ETF와 경쟁상품 ETF 2개 선정 후, 특징 비교 분석 
- 금융시장과 주식시장 전망에 따른 투자자 유의사항

# %%
# --- Prompt ---

※ 출력 결과
![](https://static.wikidocs.net/images/page/310758/3.1.3_ETF%EB%B6%84%EC%84%9D_01_%EC%A2%85%EB%AA%A9%EB%B6%84%EC%84%9D_1.png)
![](https://static.wikidocs.net/images/page/310758/3.1.3_ETF%EB%B6%84%EC%84%9D_01_%EC%A2%85%EB%AA%A9%EB%B6%84%EC%84%9D_2.png)
![](https://static.wikidocs.net/images/page/310758/3.1.3_ETF%EB%B6%84%EC%84%9D_01_%EC%A2%85%EB%AA%A9%EB%B6%84%EC%84%9D_3.png)
![](https://static.wikidocs.net/images/page/310758/3.1.3_ETF%EB%B6%84%EC%84%9D_01_%EC%A2%85%EB%AA%A9%EB%B6%84%EC%84%9D_4.png)
![](https://static.wikidocs.net/images/page/310758/3.1.3_ETF%EB%B6%84%EC%84%9D_01_%EC%A2%85%EB%AA%A9%EB%B6%84%EC%84%9D_5.png)

<br> 

#### ETF 종목추천 : 국내주식

이번에는 향후 시장 전망을 반영하여 가장 유망한 국내 주식형 ETF 3종을 엄선하고, 이에 대한 상세 분석 자료를 생성합니다.

종목 선정의 신뢰도를 높이기 위해 프롬프트 제약 조건에 운용 성과(수익률), 거래량(유동성), 순자산 규모(AUM) 등의 구체적인 기준을 명시하여 우량 상품만을 필터링하도록 설계하였습니다.

보고서의 출력 형식은 '선정 근거'와 '상품 상세 설명'뿐만 아니라 '적합한 투자자 유형'을 별도로 안내하도록 구성하였습니다. 이를 통해 투자자는 추천된 ETF가 자신의 투자 목적과 성향에 부합하는지 객관적으로 검증할 수 있습니다.


※ 프롬프트

# %%
# --- Prompt ---
# 지시문 
- 당신은 증권사에서 ETF상품 리서치를 담당하는 연구원입니다.
- 국내주식에 투자하는 ETF 중 향후 투자성과가 좋을 것으로 예상되는 ETF를 3개 선정해주세요.  

# 제약 조건 
- 반드시 최신 정보를 찾아야 합니다.
- 오늘은 [2026.2.11] 입니다. Google 검색으로 자료를 수집합니다. 
- 보고서는 객관적인 데이터와 발표자료를 근거로 출력해주세요. 
- ETF 선정시 참고기준 : 향후 투자전망에 따른 예상 운용성과(수익률), 거래량, 순자산규모, 괴리율/추적오차 등 

# ETF 정보 참조 사이트 
- https://finance.naver.com/sise/etf.naver

# 출력형식 
- ETF 선정 사유
- ETF 설명 : 투자포인트 3줄 핵심 요약, 기초지수, 구성자산(PDF), 총보수 수준, 순자산규모와 거래량 수준, 괴리율 및 추적오차, 분배금 지급 
- ETF에 적합한 투자자 안내 (타겟고객)  
- 금융시장과 주식시장 전망에 따른 투자자 유의사항

# %%
# --- Prompt ---

※ 출력 결과
![](https://static.wikidocs.net/images/page/310758/3.1.3_ETF%EB%B6%84%EC%84%9D_02_%EA%B5%AD%EB%82%B4%EC%A3%BC%EC%8B%9D_1.png)
![](https://static.wikidocs.net/images/page/310758/3.1.3_ETF%EB%B6%84%EC%84%9D_02_%EA%B5%AD%EB%82%B4%EC%A3%BC%EC%8B%9D_2.png)
![](https://static.wikidocs.net/images/page/310758/3.1.3_ETF%EB%B6%84%EC%84%9D_02_%EA%B5%AD%EB%82%B4%EC%A3%BC%EC%8B%9D_3.png)
![](https://static.wikidocs.net/images/page/310758/3.1.3_ETF%EB%B6%84%EC%84%9D_02_%EA%B5%AD%EB%82%B4%EC%A3%BC%EC%8B%9D_4.png)
![](https://static.wikidocs.net/images/page/310758/3.1.3_ETF%EB%B6%84%EC%84%9D_02_%EA%B5%AD%EB%82%B4%EC%A3%BC%EC%8B%9D_5.png)
![](https://static.wikidocs.net/images/page/310758/3.1.3_ETF%EB%B6%84%EC%84%9D_02_%EA%B5%AD%EB%82%B4%EC%A3%BC%EC%8B%9D_6.png)
![](https://static.wikidocs.net/images/page/310758/3.1.3_ETF%EB%B6%84%EC%84%9D_02_%EA%B5%AD%EB%82%B4%EC%A3%BC%EC%8B%9D_7.png)

<br> 

#### ETF 종목추천 : 미국주식

국내 ETF 분석에 적용했던 프롬프트를 미국 주식형 ETF로 확장하여 동일한 양식의 보고서를 생성합니다.

출력형식에 **글로벌 주식시장 전망에 따른 투자자 유의사항**을 생성하도록 하여, 해외 투자의 위험 요소를 회피하거나 보완할 수 있는 구체적인 대안까지 제시하도록 설계하였습니다.

※ 프롬프트

# %%
# --- Prompt ---
# 지시문 
- 당신은 증권사에서 ETF상품 리서치를 담당하는 연구원입니다.
- 미국주식에 투자하는 국내상장 ETF 중 향후 투자성과가 좋을 것으로 예상되는 ETF를 3개 선정해주세요.  

# 제약 조건 
- 반드시 최신 정보를 찾아야 합니다.
- 오늘은 [2026.2.11] 입니다. Google 검색으로 자료를 수집합니다. 
- 보고서는 객관적인 데이터와 발표자료를 근거로 출력해주세요. 
- ETF 선정시 참고기준 : 향후 투자전망에 따른 예상 운용성과(수익률), 거래량, 순자산규모, 괴리율/추적오차 등 

# ETF 정보 참조 사이트 
- https://finance.naver.com/sise/etf.naver

# 출력형식 
- ETF 선정 사유
- ETF 설명 : 투자포인트 3줄 핵심 요약, 기초지수, 구성자산(PDF), 총보수 수준, 순자산규모와 거래량 수준, 괴리율 및 추적오차, 분배금 지급 
- ETF에 적합한 투자자 안내 (타겟고객)  
- 글로벌 주식시장 전망에 따른 투자자 유의사항

# %%
# --- Prompt ---

※ 출력 결과
![](https://static.wikidocs.net/images/page/310758/3.1.3_ETF%EB%B6%84%EC%84%9D_03_%EB%AF%B8%EA%B5%AD%EC%A3%BC%EC%8B%9D_1.png)
![](https://static.wikidocs.net/images/page/310758/3.1.3_ETF%EB%B6%84%EC%84%9D_03_%EB%AF%B8%EA%B5%AD%EC%A3%BC%EC%8B%9D_2.png)
![](https://static.wikidocs.net/images/page/310758/3.1.3_ETF%EB%B6%84%EC%84%9D_03_%EB%AF%B8%EA%B5%AD%EC%A3%BC%EC%8B%9D_3.png)
![](https://static.wikidocs.net/images/page/310758/3.1.3_ETF%EB%B6%84%EC%84%9D_03_%EB%AF%B8%EA%B5%AD%EC%A3%BC%EC%8B%9D_4.png)
![](https://static.wikidocs.net/images/page/310758/3.1.3_ETF%EB%B6%84%EC%84%9D_03_%EB%AF%B8%EA%B5%AD%EC%A3%BC%EC%8B%9D_5.png)
![](https://static.wikidocs.net/images/page/310758/3.1.3_ETF%EB%B6%84%EC%84%9D_03_%EB%AF%B8%EA%B5%AD%EC%A3%BC%EC%8B%9D_6.png)


<br>

#### ETF 종목추천 : 고배당 테마

고배당주의 핵심 가치는 시장 변동성과 무관하게 창출되는 **안정적인 현금 흐름인 배당금**에 있습니다. 통상 고배당 기업들은 펀더멘털이 견고하고 잉여 현금이 풍부하여, 하락장에서 주가가 덜 하락하는 하방 경직성이 뛰어납니다. 최근 상법 개정 논의 및 배당소득 분리과세 추진 등 주주 환원 정책 강화 기조와 맞물려 투자 매력도는 더욱 확대되고 있습니다.

이번 예시에서는 배당주에 집중 투자하는 '고배당 ETF'에 대한 투자전략 보고서를 작성합니다. 국내와 해외로 나누어 ETF를 선정하고, 선정 논리와 상품 구조, 그리고 적합 투자자를 제안하도록 하였습니다.  

※ 프롬프트

# %%
# --- Prompt ---
# 지시문 
- 당신은 증권사에서 ETF상품 리서치를 담당하는 연구원입니다.
- 고배당주 업종에 투자하는 ETF상품을 선정하고 제안서를 작성해주세요. 
- ETF상품은 2개를 선정합니다. 1. 국내주식 배당 ETF, 2.해외주식 배당 ETF

# 제약 조건 
- 반드시 최신 정보를 찾아야 합니다.
- 오늘은 [2026.2.11] 입니다. Google 검색으로 자료를 수집합니다. 
- 보고서는 객관적인 데이터와 발표자료를 근거로 출력해주세요. 
- ETF 선정시 참고기준 : 향후 투자전망, 운용성과, 거래량, 순자산규모, 배당수익률, 배당성장률, 토탈리턴, 분배금 지급 주기 등 

# ETF 정보 참조 사이트 
- https://finance.naver.com/sise/etf.naver

# 출력형식 
- 배당주 투자 전망 : 국내주식, 해외주식으로 구분하여 설명 
- 추천 ETF 선정 및 설명 : 투자포인트 3줄 핵심 요약, 보유종목, 수익률(1개월/3개월/6개월/1년), 분배금 지급  
- 추천 ETF에 적합한 투자자 안내 (타겟고객)  
- 투자자 유의사항

# %%
# --- Prompt ---

※ 출력 결과
![](https://static.wikidocs.net/images/page/310758/3.1.3_ETF%EB%B6%84%EC%84%9D_04_%EA%B3%A0%EB%B0%B0%EB%8B%B9_1.png)
![](https://static.wikidocs.net/images/page/310758/3.1.3_ETF%EB%B6%84%EC%84%9D_04_%EA%B3%A0%EB%B0%B0%EB%8B%B9_2.png)
![](https://static.wikidocs.net/images/page/310758/3.1.3_ETF%EB%B6%84%EC%84%9D_04_%EA%B3%A0%EB%B0%B0%EB%8B%B9_3.png)
![](https://static.wikidocs.net/images/page/310758/3.1.3_ETF%EB%B6%84%EC%84%9D_04_%EA%B3%A0%EB%B0%B0%EB%8B%B9_4.png)

<br> 

#### ETF 종목추천 : 채권

이번에는 주식 중심의 포트폴리오를 넘어 채권 ETF로 투자 범위를 확장합니다. 투자자 관점에서 채권 투자가 갖는 핵심적인 효용은 다음과 같습니다.

- 자산 배분 효과 : 주식과 채권은 일반적으로 음(-)의 상관관계를 보입니다. 주식 시장 급락 시 채권 가격이 상승하거나 방어하는 경향이 강하기 때문에, 혼합 투자 시 포트폴리오의 전체 변동성을 낮출 수 있습니다.
- 안정적인 수익 창출 : 채권 ETF는 이자 수익을 재원으로 분배금을 지급합니다. 이는 은퇴 자금이나 생활비 마련 등 현금 흐름이 중요한 투자자에게 최적의 대안이 됩니다.
- 시세 차익 기회 : 고금리 시기에는 높은 이자 수익을 확정 짓고, 향후 금리 인하 시기에는 채권 가격 상승에 따른 매매 차익까지 동시에 누릴 수 있습니다.
- 퇴직연금 필수 자산 : 퇴직연금(DC, IRP)은 규정상 위험자산 비중이 70%로 제한됩니다. 나머지 30%의 안전자산 의무 비중을 예금 대신 채권형 ETF로 채운다면, 유동성을 확보하면서도 예금 대비 초과 수익을 기대할 수 있습니다.

다만, 채권 투자는 듀레이션(잔존만기), 신용등급, 환헤지 등 전문적인 지식이 요구됩니다. 이번 예제에서는 LLM을 통해 이러한 장벽을 해소하는데 집중합니다. 국내 및 해외 유망 채권 ETF를 추천받고, 위에서 언급한 채권 투자시 고려요소(수익률·듀레이션·신용등급 등) 를 포함하여 분석 보고서를 생성하도록 설계하였습니다

※ 프롬프트

# %%
# --- Prompt ---
# 지시문 
- 당신은 증권사에서 ETF상품 리서치를 담당하는 연구원입니다.
- 채권에 투자하는 고객을 대상으로, 국내상장 ETF 중 향후 투자성과가 좋을 것으로 예상되는 ETF를 선정해주세요. 
- ETF는 2개를 선정합니다. 국내채권 ETF 1개, 해외채권 ETF 1개

# 제약 조건 
- 반드시 최신 정보를 찾아야 합니다.
- 오늘은 [2026.2.11] 입니다. Google 검색으로 자료를 수집합니다. 
- 보고서는 객관적인 데이터와 발표자료를 근거로 출력해주세요. 
- ETF 선정시 참고기준 : 향후 투자전망에 따른 예상 운용성과(수익률), 거래량, 순자산규모, 듀레이션, 만기수익률, 채권 신용등급, 분배금, 해외채권의 경우 환헤지 여부 등 

# ETF 정보 참조 사이트 
- https://finance.naver.com/sise/etf.naver

# 출력형식 
- ETF 선정 사유
- ETF 설명 : 투자포인트 3줄 핵심 요약, 기초지수, 구성자산(PDF), 듀레이션, 신용등급, 만기수익률, 분배금, 환헤지여부
- ETF에 적합한 투자자 안내 (타겟고객)  
- 금리 및 채권시장 전망에 따른 투자자 유의사항

# %%
# --- Prompt ---

※ 출력 결과
![](https://static.wikidocs.net/images/page/310758/3.1.3_ETF%EB%B6%84%EC%84%9D_05_%EC%B1%84%EA%B6%8C_1.png)
![](https://static.wikidocs.net/images/page/310758/3.1.3_ETF%EB%B6%84%EC%84%9D_05_%EC%B1%84%EA%B6%8C_2.png)
![](https://static.wikidocs.net/images/page/310758/3.1.3_ETF%EB%B6%84%EC%84%9D_05_%EC%B1%84%EA%B6%8C_3.png)
![](https://static.wikidocs.net/images/page/310758/3.1.3_ETF%EB%B6%84%EC%84%9D_05_%EC%B1%84%EA%B6%8C_4.png)
![](https://static.wikidocs.net/images/page/310758/3.1.3_ETF%EB%B6%84%EC%84%9D_05_%EC%B1%84%EA%B6%8C_5.png)

<br> 

#### ETF 종목추천 : 원자재

대체 투자 자산인 원자재 ETF를 분석하고 추천 보고서를 생성합니다.

원자재는 인플레이션 국면에서 화폐 가치 하락을 방어하는 강력한 헤지(Hedge) 수단이자, 전통적 자산인 주식·채권과 상관관계가 낮아 포트폴리오의 전체 위험을 낮추는 분산 투자 효과가 탁월합니다. 반면, 높은 가격 변동성과 지정학적 리스크, 기후 변화 및 산유국 정책 등 예측 불가능한 대외 변수에 민감하다는 양면성이 존재합니다.

이번에는 LLM을 활용하여 에너지, 금속, 농산물 등 원자재 유형별 투자 전망을 입체적으로 요약하고, 그중 가장 유망한 ETF를 선별합니다. 특히 보고서 생성 시 제약조건 섹션을 강화하여, 원자재 투자에 수반되는 잠재적 위험 요소를 사전에 식별하고 대응할 수 있도록 설계하였습니다.

※ 프롬프트

# %%
# --- Prompt ---
# 지시문 
- 당신은 증권사에서 ETF상품 리서치를 담당하는 연구원입니다.
- 원자재에 투자하는 고객을 대상으로, 국내상장 ETF 중 투자성과가 좋을 것으로 예상되는 ETF를 선정해주세요. 

# 제약 조건 
- 반드시 최신 정보를 찾아야 합니다.
- 오늘은 [2026.2.11] 입니다. Google 검색으로 자료를 수집합니다. 
- 보고서는 객관적인 데이터와 발표자료를 근거로 출력해주세요. 
- ETF 선정시 참고기준 : 향후 투자전망에 따른 예상 운용성과(수익률), 현물 또는 선물 여부, 롤오버 비용 발생 여부, 환헤지 여부 등 

# ETF 정보 참조 사이트 
- https://finance.naver.com/sise/etf.naver

# 출력형식 
- 원자재별 투자 전망 : 에너지, 귀금속(금/은), 산업금속(구리/리튬/회토류 등), 농산물 
- 추천 ETF 선정 및 설명 : 투자포인트 3줄 핵심 요약, 보유종목, 수익률(1개월/3개월/6개월/1년), 분배금 지급  
- 추천 ETF에 적합한 투자자 안내 (타겟고객)  
- 투자자 유의사항

# %%
# --- Prompt ---

※ 출력 결과
![](https://static.wikidocs.net/images/page/310758/3.1.3_ETF%EB%B6%84%EC%84%9D_06_%EC%9B%90%EC%9E%90%EC%9E%AC_1.png)
![](https://static.wikidocs.net/images/page/310758/3.1.3_ETF%EB%B6%84%EC%84%9D_06_%EC%9B%90%EC%9E%90%EC%9E%AC_2.png)
![](https://static.wikidocs.net/images/page/310758/3.1.3_ETF%EB%B6%84%EC%84%9D_06_%EC%9B%90%EC%9E%90%EC%9E%AC_3.png)
![](https://static.wikidocs.net/images/page/310758/3.1.3_ETF%EB%B6%84%EC%84%9D_06_%EC%9B%90%EC%9E%90%EC%9E%AC_4.png)
![](https://static.wikidocs.net/images/page/310758/3.1.3_ETF%EB%B6%84%EC%84%9D_06_%EC%9B%90%EC%9E%90%EC%9E%AC_5.png)

<br> 

#### ETF 종목추천 : 멀티팩터 (국내주식)

필자가 ETF 종목발굴 시 가장 신뢰하고 선호하는 멀티팩터 기반의 LLM 프롬프트를 소개합니다.

2장에서 학습한 멀티팩터 전략을 ETF 분석과 추천에 이식하여 모멘텀, 밸류, 퀄러티 등 세 가지 핵심 지표를 기준으로 평가합니다. 이를 통해 추천 ETF의 선정 배경과 논리를 입체적으로 조망할 수 있는 보고서를 생성할 수 있습니다. 

※ 프롬프트

# %%
# --- Prompt ---
# 지시문 
- 당신은 증권사에서 ETF상품 리서치를 담당하는 연구원이자 퀀트 투자 전략가입니다.
- 주식시장의 이슈와 트렌드를 분석하여, 향후 투자 전망이 우수한 ETF를 추천해주세요. 
- ETF 종목 추출은 멀티팩터 모델 기법을 적용해주세요. 

# 제약 조건 
- 최근의 국내 경제, 금융, 주식시장의 주요 이슈와 뉴스를 수집해서 분석합니다.  
- 오늘은 [2026.2.11] 입니다. Google 검색으로 자료를 수집합니다. 
- 앞으로 3개월간 주가 상승률이 가장 높을 것으로 예상되는 3개 섹터를 추출 합니다. 
- 유망 섹터를 추출할 때에는 멀티팩터 지표인 모멘텀, 밸류, 퀄러티 지표를 고려하고 근거에 포함해주세요. 
- 멀티팩터 지표는 다음과 같이 7가지로 정의 합니다. 
  - 모멘텀 지표 : 주가, 거래량 
  - 밸류 지표 : PER, PBR
  - 퀄러티 지표 : 매출액 증가율, 영업이익 증가율, 순이익 증가율 
- 보고서는 객관적인 데이터와 발표자료를 근거로 출력해주세요. 

# 출력형식 
- 멀티팩터 관점으로 향후 3개월 간 투자 유망 섹터를 3개 나열하고, 근거를 제시 합니다.
- 3개 유망 섹터내에서 주가 상승률이 높을 것으로 예상되는 ETF를 1개씩 선정합니다. (총 3개)
- ETF 설명 : 투자포인트 3줄 핵심 요약, 보유종목, 수익률(1개월/3개월/6개월/1년), 분배금 지급
- ETF에 적합한 투자자 안내 (타겟고객)  
- 투자자 유의사항

# %%
# --- Prompt ---
# 지시문 
- 당신은 증권사에서 ETF상품 리서치를 담당하는 연구원이자 퀀트 투자 전략가입니다.
- 미국주식에 투자하는 국내상장 ETF 중 향후 투자성과가 좋을 것으로 예상되는 ETF를 3개 선정해주세요.   
- ETF 종목 추출은 멀티팩터 모델 기법을 적용해주세요. 

# 제약 조건 
- 최근의 미국 경제, 금융, 주식시장의 주요 이슈와 뉴스를 수집해서 분석합니다.  
- 오늘은 [2026.2.11] 입니다. Google 검색으로 자료를 수집합니다. 
- 앞으로 3개월간 주가 상승률이 가장 높을 것으로 예상되는 3개 섹터를 추출 합니다. 
- 유망 섹터를 추출할 때에는 멀티팩터 지표인 모멘텀, 밸류, 퀄러티 지표를 고려하고 근거에 포함해주세요. 
- 멀티팩터 지표는 다음과 같이 7가지로 정의 합니다. 
  - 모멘텀 지표 : 주가, 거래량 
  - 밸류 지표 : PER, PBR
  - 퀄러티 지표 : 매출액 증가율, 영업이익 증가율, 순이익 증가율 
- 보고서는 객관적인 데이터와 발표자료를 근거로 출력해주세요. 

# 출력형식 
- 미국주식 시장에서 멀티팩터 관점으로 향후 3개월 간 투자 유망 섹터를 3개 나열하고, 근거를 제시 합니다.
- 3개 유망 섹터내에서 주가 상승률이 높을 것으로 예상되는 국내상장 ETF를 1개씩 선정합니다. (총 3개)
- ETF 설명 : 투자포인트 3줄 핵심 요약, 보유종목, 수익률(1개월/3개월/6개월/1년), 분배금 지급
- ETF에 적합한 투자자 안내 (타겟고객)  
- 투자자 유의사항

# %%
# --- Prompt ---

※ 출력 결과
![](https://static.wikidocs.net/images/page/310758/3.1.3_ETF%EB%B6%84%EC%84%9D_08_%EB%A9%80%ED%8B%B0%ED%8C%A9%ED%84%B0%EB%AF%B8%EA%B5%AD_1.png)
![](https://static.wikidocs.net/images/page/310758/3.1.3_ETF%EB%B6%84%EC%84%9D_08_%EB%A9%80%ED%8B%B0%ED%8C%A9%ED%84%B0%EB%AF%B8%EA%B5%AD_2.png)
![](https://static.wikidocs.net/images/page/310758/3.1.3_ETF%EB%B6%84%EC%84%9D_08_%EB%A9%80%ED%8B%B0%ED%8C%A9%ED%84%B0%EB%AF%B8%EA%B5%AD_3.png)
![](https://static.wikidocs.net/images/page/310758/3.1.3_ETF%EB%B6%84%EC%84%9D_08_%EB%A9%80%ED%8B%B0%ED%8C%A9%ED%84%B0%EB%AF%B8%EA%B5%AD_4.png)
![](https://static.wikidocs.net/images/page/310758/3.1.3_ETF%EB%B6%84%EC%84%9D_08_%EB%A9%80%ED%8B%B0%ED%8C%A9%ED%84%B0%EB%AF%B8%EA%B5%AD_5.png)
![](https://static.wikidocs.net/images/page/310758/3.1.3_ETF%EB%B6%84%EC%84%9D_08_%EB%A9%80%ED%8B%B0%ED%8C%A9%ED%84%B0%EB%AF%B8%EA%B5%AD_6.png)

<br> 

#### ETF 종목추천 : 고객성향별(적극투자형/안정추구형) 

이번에는 고객의 **위험 선호도**에 최적화된 맞춤형 ETF 포트폴리오를 제안합니다. 

투자자 유형을 **적극투자형(공격형)** 과 **안정추구형(안정형)** 으로 분류하고, 투자성향과 향후 투자전망을 동시에 고려하여 ETF를 추천하도록 하였습니다. 

※ 프롬프트

# %%
# --- Prompt ---
# 지시문 
- 당신은 증권사에서 ETF상품 리서치를 담당하는 연구원입니다.
- 투자에 유망한 국내상장 ETF상품을 선정하고 제안서를 작성해주세요. 

# 제약 조건 
- 반드시 최신 정보를 찾아야 합니다.
- 오늘은 [2026.2.11] 입니다. Google 검색으로 자료를 수집합니다. 
- 국내주식, 해외주식, 채권시장 및 원자재 주요 이슈와 ETF 관련 뉴스 및 상품 정보를 수집해서 분석합니다.  
- 다음의 두 가지 유형을 고려하여 가장 적합한 ETF를 추천합니다. : 1.공격형투자자 2.안정형투자자
- ETF 선정시 참고기준 : 향후 투자전망, 운용성과, 거래량, 순자산규모, 괴리율/추적오차 등 
- 보고서는 객관적인 데이터와 발표자료를 근거로 출력해주세요. 

# ETF 정보 참조 사이트 
- https://finance.naver.com/sise/etf.naver

# 출력형식 
- ETF 투자 관점에서 현재 금융시장 트렌드 분석
- 공격형 투자자 대상 추천 ETF 3개 : 투자포인트 3줄 핵심 요약, 보유종목, 수익률(1개월/3개월/6개월/1년), 분배금 지급
- 안정형 투자자 대상 추천 ETF 3개 : 투자포인트 3줄 핵심 요약, 보유종목, 수익률(1개월/3개월/6개월/1년), 분배금 지급 
- 투자자 유의사항

# %%
# --- Prompt ---

※ 출력 결과 
![](https://static.wikidocs.net/images/page/310758/3.1.3_ETF%EB%B6%84%EC%84%9D_09_%EA%B3%A0%EA%B0%9D%EC%84%B1%ED%96%A5_1.png)
![](https://static.wikidocs.net/images/page/310758/3.1.3_ETF%EB%B6%84%EC%84%9D_09_%EA%B3%A0%EA%B0%9D%EC%84%B1%ED%96%A5_2.png)
![](https://static.wikidocs.net/images/page/310758/3.1.3_ETF%EB%B6%84%EC%84%9D_09_%EA%B3%A0%EA%B0%9D%EC%84%B1%ED%96%A5_3.png)
![](https://static.wikidocs.net/images/page/310758/3.1.3_ETF%EB%B6%84%EC%84%9D_09_%EA%B3%A0%EA%B0%9D%EC%84%B1%ED%96%A5_4.png)
![](https://static.wikidocs.net/images/page/310758/3.1.3_ETF%EB%B6%84%EC%84%9D_09_%EA%B3%A0%EA%B0%9D%EC%84%B1%ED%96%A5_5.png)
![](https://static.wikidocs.net/images/page/310758/3.1.3_ETF%EB%B6%84%EC%84%9D_09_%EA%B3%A0%EA%B0%9D%EC%84%B1%ED%96%A5_6.png)
![](https://static.wikidocs.net/images/page/310758/3.1.3_ETF%EB%B6%84%EC%84%9D_09_%EA%B3%A0%EA%B0%9D%EC%84%B1%ED%96%A5_7.png)
![](https://static.wikidocs.net/images/page/310758/3.1.3_ETF%EB%B6%84%EC%84%9D_09_%EA%B3%A0%EA%B0%9D%EC%84%B1%ED%96%A5_8.png)

<br> 

#### ETF 추천 : 연금투자  

이번에는 LLM을 활용하여 은퇴 준비를 위한 **퇴직연금 ETF 포트폴리오 제안서**를 작성합니다.

시나리오는 단순한 자산 증식을 넘어, 10년 장기 적립식 투자를 가정한 연금 운용 계획에 초점을 맞췄습니다. 프롬프트에는 주식과 채권의 혼합을 통한 자산 배분과 국가를 넘나드는 지역별 분산 투자 원칙을 적용하여 리스크를 최소화하도록 설계하였습니다.

이를 통해 사용자는 증권사 PB(Private Banker)를 방문하지 않고도, 금융시장과 ETF 상품, 복잡한 퇴직연금 제도까지 학습한 **AI 투자비서**로부터 고품질의 재무설계 제안서를 즉시 받아볼 수 있습니다.

※ 프롬프트

# %%
# --- Prompt ---
# 지시문
- 당신은 증권사에서 고객자산을 관리하고 있는 전문 PB입니다.
- 퇴직연금(IRP/DC) 자산을 국내상장 ETF로 분산투자하고자 하는 고객을 위하여 [투자제안서]를 작성해주세요.
- 고객은 10년 후 은퇴자금 마련을 위해, 10년간 월별로 50만원씩 퇴직연금 계좌에 적립식으로 투자할 계획입니다.
- 아래 제약 조건을 철저히 준수하여, 국내 주식형 ETF를 포함한 총 5개의 ETF를 제안해주세요.

# 제약 조건
- 시점 및 정보 수집: 오늘은 [2026년 2월 19일]입니다. Google 검색을 통해 이 시점의 최신 경제 지표와 시장 이슈를 수집합니다. 
- 포트폴리오 구성 원칙 (필수 준수):
 . 지역 배분: 반드시 '국내 주식형 ETF'를 1개 이상 포함해야 합니다. (예: KOSPI200, 반도체, 2차전지, 고배당 등 국내 유망 섹터나 지수)
 . 자산 배분: 국내주식, 해외주식(선진국/신흥국), 채권/대체자산 간의 균형을 맞추어 제안합니다. 
 . 위험 관리: 환노출/환헤지 여부와 변동성을 고려하여 안정성과 수익성을 동시에 추구합니다.  
- 세제 혜택 고려: 퇴직연금 계좌의 과세이연 및 연금 수령 시 절세 효과를 고려하여, 해외 주식형이나 채권형 ETF의 이점을 활용합니다. 
- 근거 기반: 모든 제안은 객관적인 데이터(지수, 수익률, 시황 등)에 기반해야 합니다.

# 출력 형식
- 시장 동향 및 전망 (2026.02.19 기준)
글로벌/국내 주식 시장, 채권 및 원자재 시장의 핵심 이슈 요약
- 퇴직연금 ETF 포트폴리오 제안 (총 5개)
다음 양식에 맞춰 표(Table) 또는 리스트로 정리
 . [국내 주식] 1~2종: 종목명(코드), 선정 사유(투자 포인트), 최근 1년 수익률, 총보수
 . [해외 주식] 2~3종: 종목명(코드), 선정 사유, 최근 1년 수익률, 총보수
 . [채권/안전] 1종 이상: 종목명(코드), 선정 사유, 최근 1년 수익률, 총보수
 . 추천 투자 비중: (예: 국내 20%, 해외 50%, 채권 30%)
- 은퇴 자금 시뮬레이션
 . 투자 기간 10년, 월 50만 원 적립 시 예상 평가 금액
 . 시나리오별 가정: Best(연 10%), Middle(연 6%), Worst(연 3%)
- 리밸런싱 및 관리 전략
 . 국내/해외 비중 조절 및 수익 실현 타이밍 제안
- 투자자 유의사항
 . 원금 손실 위험 및 퇴직연금 운용 시 주의점

# %% [markdown]
# ### 3 1 4 펀드 분석하기.md

# %%
# --- Prompt ---
# 지시문 
- 당신은 증권사에서 펀드 상품 리서치를 담당하는 연구원입니다.
- 고객 대상으로 펀드 제안서를 작성해주세요.  

# 대상 펀드 
- 미래에셋코어테크펀드 

# 제약 조건 
- 반드시 최신 정보를 찾아야 합니다.
- 오늘은 [2026.2.19] 입니다. Google 검색으로 자료를 수집합니다. 
- 금융 및 펀드에 대한 어려운 용어는 일반 투자자 관점으로 쉽게 설명해주세요. 
- 보고서는 객관적인 데이터와 발표자료를 근거로 작성해주세요. 

# 펀드 정보 참조 사이트 
- https://www.funetf.co.kr/product/fund/filter
- https://funddoctor.co.kr/afn/topfund/fundrate1.jsp?page=1

# 출력형식 
- 대상 펀드의 투자전략, 투자포인트, 최근수익률(3개월/1년), 설정액, 보유종목, 타겟고객, 투자자유의사항 
- 2026년 대상 펀드의 운용성과 전망
- 대상 펀드와 유사한 경쟁 펀드를 1개 선정하고, 주요 특징 비교표 작성 : 투자포인트, 수익률(3개월/1년), 보유종목, 투자전망

# %%
# --- Prompt ---

※ 출력 결과 
![](https://static.wikidocs.net/images/page/304601/3.1.4_%ED%8E%80%EB%93%9C%EB%B6%84%EC%84%9D_01_%EC%9A%B4%EC%9A%A9%EB%B3%B4%EA%B3%A0%EC%84%9C_1.png)
![](https://static.wikidocs.net/images/page/304601/3.1.4_%ED%8E%80%EB%93%9C%EB%B6%84%EC%84%9D_01_%EC%9A%B4%EC%9A%A9%EB%B3%B4%EA%B3%A0%EC%84%9C_2.png)
![](https://static.wikidocs.net/images/page/304601/3.1.4_%ED%8E%80%EB%93%9C%EB%B6%84%EC%84%9D_01_%EC%9A%B4%EC%9A%A9%EB%B3%B4%EA%B3%A0%EC%84%9C_3.png)

<br> 

#### 펀드 추천 : 목적자금 마련 맞춤형 투자설계

이번에는 고객의 재무상황과 투자목표를 정밀하게 분석하여 펀드를 추천하고, 목표 달성 가능성을 진단하는 **맞춤형 투자 설계 보고서**를 작성합니다. 통상 고액 자산가들이 PB(Private Banker)에게 제공받던 전문적인 재무설계 서비스를 LLM에 정교한 설계 로직을 주입함으로써 구현할 수 있습니다.

예제에서는 **20년 장기 적립식 투자**를 통해 **1억 원의 목돈 마련**을 목표로 설정하였습니다. 보고서에는 투자기간 동안 기대수익률 변화에 따른 최종 목표금액을 예측하는 **재무설계 시뮬레이션** 결과를 포함하도록 설계했습니다.

특히 본 예제에서는 은퇴 시점에 맞춰 주식과 채권 비중을 자동으로 조절하는 **TDF(Target Date Fund)** 를 핵심 솔루션으로 채택하였습니다. 프롬프트에 TDF의 구조와 장점을 상세히 학습시켜, 고객에게 최적화된 상품 설명이 제공되도록 하였습니다. 

※ 프롬프트

# %%
# --- Prompt ---
# 지시문 
- 당신은 증권사에서 고객자산을 관리하고 있는 PB입니다.
- 고객은 45세 남성 직장인으로 20년 후 국민연금 수령 전까지 월 적립식으로 투자하여, 1억원의 목돈을 마련하고자 합니다.
- 고객의 투자기간과 투자금액 및 TDF펀드의 상품 컨셉에 맞추어 투자 제안서를 만들어주세요. 

# 제약 조건 
- 반드시 최신 정보를 찾아야 합니다.
- 오늘은 [2026.2.19] 입니다. Google 검색으로 자료를 수집합니다. 
- 보고서는 객관적인 데이터와 발표자료를 근거로 출력해주세요. 

# 출력형식 
- TDF펀드에 대한 설명 
- TDF펀드 추천 펀드 포트폴리오 제안 : 펀드명, 선정사유, 투자포인트, 유의사항 
- 투자기간(20년)의 기대수익률(I%)에 따른 최종평가금액(FV) 시뮬레이션 출력 : 기대수익률은 3개 시나리오 가정(Best, Middle, Worst)
- 펀드 포트폴리오의 정기 리밸런싱 전략 제안 
- 투자자 유의사항

# %%
# --- Prompt ---

※ 출력 결과 
![](https://static.wikidocs.net/images/page/304601/3.1.4_%ED%8E%80%EB%93%9C%EB%B6%84%EC%84%9D_02_TDF_1.png)
![](https://static.wikidocs.net/images/page/304601/3.1.4_%ED%8E%80%EB%93%9C%EB%B6%84%EC%84%9D_02_TDF_2.png)
![](https://static.wikidocs.net/images/page/304601/3.1.4_%ED%8E%80%EB%93%9C%EB%B6%84%EC%84%9D_02_TDF_3.png)
![](https://static.wikidocs.net/images/page/304601/3.1.4_%ED%8E%80%EB%93%9C%EB%B6%84%EC%84%9D_02_TDF_4.png)
![](https://static.wikidocs.net/images/page/304601/3.1.4_%ED%8E%80%EB%93%9C%EB%B6%84%EC%84%9D_02_TDF_5.png)

<br> 

#### 펀드 추천 : 펀드 유형별 투자유망펀드 제안서

이번에는 펀드를 핵심 자산군인 국내 주식형, 해외 주식형, 채권형의 3대 유형으로 분류하고, 각 부문별 최선호 펀드를 발굴합니다.

분석 대상인 투자 유니버스는 **공모 펀드**로 한정하였습니다. ETF(상장지수펀드)와 사모 펀드는 제외하여 전통적인 뮤추얼 펀드만 추출되도록 하였습니다. 

신뢰도 높은 추천을 위해 제약 조건에 최소 설정액 기준을 명기하여 유동성이 부족한 소규모 펀드를 제외하였습니다. 최종 추천 펀드는 자금 유입 강도(설정액 증가), 운용 성과(수익률), 향후 성장성(전망)을 종합적으로 평가하여 결정하도록 하였습니다. 

보고서의 출력 형식은 **시장 전망 분석** 이후에 **유망 펀드 추천**의 탑다운(Top-Down) 구조를 채택했습니다. 이를 통해 거시적인 시장 흐름을 요약하고, 이에 부합하는 펀드를 추천하는 자연스러운 흐름으로 구성하도록 하였습니다. 

※ 프롬프트

# %%
# --- Prompt ---
# 지시문 
- 당신은 증권사에서 펀드 상품 리서치를 담당하는 연구원입니다.
- 고객 대상으로 배포할 투자 유망 펀드 보고서를 작성해주세요.  
- 보고서 작성시 ETF(상장지수펀드)는 제외하고, 공모형 뮤추얼 펀드만 집계 합니다.  

# 제약 조건 
- 반드시 최신 정보를 찾아야 합니다.
- 오늘은 [2026.2.19] 입니다. Google 검색으로 자료를 수집합니다. 
- 펀드는 3가지 유형으로 구분합니다. 국내주식형, 해외주식형, 채권형 
- 펀드 설정액 500억 이상 펀드를 대상으로 합니다. 
- 다음 기준을 참조하여 투자 유망 펀드를 선정합니다. 설정액 증가, 1년 수익률 우수, 향후 투자전망 우수  
- 투자유망 펀드 보고서는 국내주식형/해외주식형/채권형별로 1위부터 3위까지 작성합니다. (총 9개 펀드)   
- 보고서는 객관적인 데이터와 발표자료를 근거로 출력해주세요. 

# 펀드 정보 참조 사이트 
- https://www.funetf.co.kr/product/fund/filter
- https://funddoctor.co.kr/afn/topfund/fundrate1.jsp?page=1

# 출력형식 
- 2026년 국내주식시장, 해외주식시장, 채권시장 투자전망 요약
- 국내주식형 펀드 추천  : 펀드명, 보유종목, 투자포인트, 기대수익률, 투자자유의사항 
- 해외주식형 펀드 추천  : 펀드명, 보유종목, 투자포인트, 기대수익률, 투자자유의사항 
- 채권형 펀드 추천  :  펀드명, 보유종목, 투자포인트, 기대수익률, 투자자유의사항

# %%
# --- Prompt ---

※ 출력 결과
![](https://static.wikidocs.net/images/page/304601/3.1.4_%ED%8E%80%EB%93%9C%EB%B6%84%EC%84%9D_03_%EC%9C%A0%ED%98%95%EB%B3%84%EC%B6%94%EC%B2%9C_1.png)
![](https://static.wikidocs.net/images/page/304601/3.1.4_%ED%8E%80%EB%93%9C%EB%B6%84%EC%84%9D_03_%EC%9C%A0%ED%98%95%EB%B3%84%EC%B6%94%EC%B2%9C_2.png)
![](https://static.wikidocs.net/images/page/304601/3.1.4_%ED%8E%80%EB%93%9C%EB%B6%84%EC%84%9D_03_%EC%9C%A0%ED%98%95%EB%B3%84%EC%B6%94%EC%B2%9C_3.png)
![](https://static.wikidocs.net/images/page/304601/3.1.4_%ED%8E%80%EB%93%9C%EB%B6%84%EC%84%9D_03_%EC%9C%A0%ED%98%95%EB%B3%84%EC%B6%94%EC%B2%9C_4.png)
![](https://static.wikidocs.net/images/page/304601/3.1.4_%ED%8E%80%EB%93%9C%EB%B6%84%EC%84%9D_03_%EC%9C%A0%ED%98%95%EB%B3%84%EC%B6%94%EC%B2%9C_5.png)
![](https://static.wikidocs.net/images/page/304601/3.1.4_%ED%8E%80%EB%93%9C%EB%B6%84%EC%84%9D_03_%EC%9C%A0%ED%98%95%EB%B3%84%EC%B6%94%EC%B2%9C_6.png)

<br>

#### 펀드 추천 : 연금투자 포트폴리오 제안서 

마지막으로 **3.1 LLM 활용하기**의 내용을 총망라한, 필자가 가장 신뢰하고 애용하는 **퇴직연금 마스터 프롬프트**를 공개합니다. 긴 호흡으로 안정적인 자산 증식이 필요한 연금 투자자에게 가장 권장하는 프롬프트 입니다.

프롬프트는 구체적인 투자 시나리오(10년 적립/월 50만 원)를 기반으로 작동합니다. 제약조건에는 글로벌 자산 배분과 위험 분산 원칙을 고려하고, 벤치마크 대비 초과 성과, 펀드 평가 등급, 운용 규모(AUM) 등 엄격한 정량적 평가 기준을 적용하여 펀드를 선정하도록 하였습니다. 또한 퇴직연금 절세 혜택까지 재무설계 로직에 반영하도록 지시했습니다.

결과 보고서는 단순한 포트폴리오 추천에 그치지 않습니다. 기대 수익률에 따른 최종 자산의 시뮬레이션 결과를 제시하여 미래 가치를 측정하고, 정기적인 리밸런싱(Rebalancing) 및 성과 모니터링 가이드까지 제공하여 투자의 시작부터 사후 관리까지 책임지는 완결형 투자 제안서를 구현하도록 하였습니다. 

※  프롬프트

# %%
# --- Prompt ---
# 지시문 
- 당신은 증권사에서 고객자산을 관리하고 있는 PB입니다.
- 퇴직연금 자산을 펀드로 분산투자하고자 하는 고객을 위하여 투자제안서를 만들어주세요.
- 고객은 10년 후 은퇴자금 마련을 위해, 10년간 월별로 50만원씩 퇴직연금 계좌에 펀드를 투자할 계획입니다.
- 제약 조건을 고려하여, 5개의 펀드를 제안해주세요. 

# 제약 조건 
- 반드시 최신 정보를 찾아야 합니다.
- 오늘은 [2026.2.19] 입니다. Google 검색으로 자료를 수집합니다. 
- 글로벌 금융시장, 채권시장의 주요 이슈와 펀드 관련 뉴스 및 상품 정보를 수집해서 분석합니다.  
- 펀드 선정시 글로벌 분산투자, 위험분산을 고려합니다. 
- 동일 유형에서 펀드 선정시 다음을 참조합니다. : 벤치마크 대비 성과, 펀드평가등급, 펀드 순자산 규모 등
- 고객의 투자기간과 투자금액, 은퇴 기간을 고려합니다. 
- 퇴직연금의 절세제도를 고려합니다. (세액공제, 과세이연, 연금소득세 등) 
- 보고서는 객관적인 데이터와 발표자료를 근거로 출력해주세요. 

# 출력형식 
- 글로벌 및 국내주식 및 채권시장 동향 및 향후 전망 
- 분산투자를 위한 펀드 포트폴리오 제안 : 펀드명, 선정사유, 펀드투자포인트, 투자비중 
- 투자기간(10년)의 기대수익률(I%)에 따른 최종평가금액(FV) 시뮬레이션 출력 : 수익률은 3개 시나리오 가정(Best, Middle, Worst)
- 펀드 포트폴리오의 정기 리밸런싱 전략 제안 
- 투자자 유의사항

# %% [markdown]
# ### 3 2 1 MCP 사용 준비.md

# %%
# --- Prompt ---
node -v
npm -v

# %% [markdown]
# ### 3 2 2 상용 MCP 활용하기.md

# %%
# --- Prompt ---
{
  "mcpServers": {
    "firecrawl-mcp": {
      "command": "npx",
      "args": ["-y", "firecrawl-mcp"],
      "env": {
        "FIRECRAWL_API_KEY": "{내 firecrawl API KEY}"
      }
    }
  }
}

# %%
# --- Prompt ---

### 3.  Claude에서의 MCP 활용

Claude 를 종료 후 재시작하면

# %%
# --- Prompt ---
iwr https://astral.sh/uv/install.ps1 -UseBasicParsing | iex

# %%
# --- Prompt ---
![](https://static.wikidocs.net/images/page/310023/image_202512021140.png)
![](https://static.wikidocs.net/images/page/310023/image_202602021252.png)

설치가 완료된 후

# %%
# --- Prompt ---
uv --version

# %%
# --- Prompt ---

![](https://static.wikidocs.net/images/page/310023/image_202602021251.png)

> 설치가 잘 완료되어 version 확인이 가능합니다.

 
### 3.  Claude의

# %%
# --- Prompt ---
{
  "mcpServers": {
    "firecrawl-mcp": {
      "command": "npx",
      "args": ["-y", "firecrawl-mcp"],
      "env": {
        "FIRECRAWL_API_KEY": "{내 firecrawl API KEY}"
      }
    },
"alphavantage": {
      "command": "uvx",
      "args": ["av-mcp", "{내 alpha vantage API KEY}"]
    }
  }
}

# %%
# --- Prompt ---

### 4.  Claude에서의 MCP 활용

Claude 를 종료 후 재시작하면 Alpha Vantage가 추가되었음을 확인할 수 있습니다.

![](https://static.wikidocs.net/images/page/310023/image_202512021144.png)

이제 이 Alpha Vantage MCP 를 활용해서 최근3년치 주가 분석이 가능합니다.
![](https://static.wikidocs.net/images/page/310023/image_202512021110.png)
>애플(AAPL)의 최근 3년 주가 조회 

이제, 모멘텀 투자의 대표적인 지수인 RSI 지수*를 바탕으로 전세계적으로 주목받는 M7 종목의 매수 매도 의견을 물어볼수 있습니다. Alpha Vantage 에서는 내부에 계산된 RSI 지표를 바탕으로 필요한 종목의 데이터를 전달해주고, 이를 바탕을 LLM이 [최종 분석결과](https://claude.ai/public/artifacts/9b6503cb-15c3-4958-baf0-349cd3cc1af2)를 알려줍니다.

![](https://static.wikidocs.net/images/page/310023/image_202512171512.png)
> Alpha Vantage를 통해서 M7 종목 주가의 RSI 지수 기반 매수, 매도의견 알려줘


|* 💡 RSI(Relative Strength Index) 지수란? | 
| -------- | 
| **상대강도지수(RSI)**는 주식 시장에서 가장 널리 쓰이는 모멘텀 지표 중 하나입니다. 쉽게 말해, 현재 주가가 '너무 많이 올랐는지(과열)' 아니면 **'지나치게 떨어졌는지(침체)'**를 0부터 100 사이의 숫자로 보여주는 속도계와 같습니다. <br> 70 이상 (과매수 구간): 주가가 단기간에 너무 많이 올랐다는 신호입니다. 차익 실현 매물이 쏟아질 수 있어 **'매도'**를 고려하는 시점입니다. <br> 30 이하 (과매도 구간): 주가가 지나치게 많이 떨어졌다는 신호입니다. 저가 매수세가 들어올 수 있어 **'매수'**를 고려하는 시점입니다.   | 




---


## MCP를 활용해서 멀티팩터 분석하기

지금까지 과정을 통해 준비된

# %%
# --- Prompt ---
# 지시문 
- 당신은 미국 경제 전문가이자 퀀트 투자 전략가입니다.
- 최근 미국 주식시장의 뉴스와 관련 자료를 학습하여, 멀티팩터 세부 지표별로 주가 예측 중요도를 분석해주세요. 
- 분석 결과는 멀티팩터 세부 지표의 가중치 조정에 활용할 예정입니다. 
# 제약 조건 
- 최근 3개월간의 미국 경제, 금융, 주식시장의 주요 이슈와 뉴스를 수집해서 분석합니다.
- 오늘은 [2025년12월 16일] 입니다. Firecrawl MCP 를 활용하여 뉴스 자료를 수집합니다.   
- Alpha Vantage MCP를 활용하여 주가정보를 수집합니다.
- 멀티팩터 지표는 다음과 같이 7가지로 정의 합니다. 
  - 모멘텀 지표 : 주가, 거래량 
  - 밸류 지표 : PER, PBR
  - 퀄러티 지표 : 매출액 증가율, 영업이익 증가율, 순이익 증가율 
- 앞으로 3개월간의 주가를 예측할 때, 멀티팩터 세부 지표별 중요도를 계량적으로 분석합니다. 
- 보고서는 객관적인 데이터와 발표자료를 근거로 출력해주세요. 
# 출력형식 
- 멀티팩터 지표를 나열하고, 각 지표별로 주가 예측에 대한 중요도를 퍼센트 비중으로 표현합니다. 
- 멀티팩터 지표를 나열하고, 중요도를 선정한 근거를 제시합니다.

# %%
# --- Prompt ---

최종적으로 Firecrawl은 DuckDuckGo 검색 결과에서 추출한 10개의 최신 웹 데이터를 수집했고, Alpha Vantage에서는 10개의 실시간 금융 뉴스 데이터를 수집했습니다.

![](https://static.wikidocs.net/images/page/310023/image_202512180936.png)

구체적으로 살펴보면:

 Firecrawl은 미국 상무부 경제분석국(BEA), 노동통계국(BLS), 필라델피아 연준 등 정부 기관과 전문 연구소의 웹사이트를 크롤링했습니다. 이를 통해 2024년 4분기 GDP 성장률, 고용 통계, 인플레이션 수치 등 객관적이고 신뢰도 높은 경제 지표와 공식 전망 보고서를 확보했습니다.

한편, Alpha Vantage는 CNBC, MarketWatch, Investopedia 등 영향력 있는 금융 언론사의 최신 기사를 수집했습니다. 여기에는 연준(Fed)의 금리 인하 결정과 그에 따른 주식 시장의 반응 등 시장의 심리와 즉각적인 동향을 파악할 수 있는 실시간 뉴스 데이터가 담겨 있습니다. 또한, S&P 500 지수를 추종하는 'SPY'의 가격 데이터까지 확보했습니다. 이를 통해 뉴스가 발생했을 때 실제 시장 지수가 어떻게 변동했는지 정량적인 흐름까지 함께 파악했습니다.

이 두 도구를 통해 거시경제 지표 데이터와 실시간 시장 반응이라는 두 가지 핵심 축의 데이터를 모두 확보하였으며 이를 통하여 미국 S&P 지수의 각 팩터별 현황을 알 수 있었습니다.

---

두번째로는 종목 및 산업분석 관점에서 아래와 같은 프롬포트로

# %%
# --- Prompt ---
# 지시문 
- 당신은 증권사에서 반도체 업종을 담당하고 있는 리서치 연구원입니다.
- 반도체 업종에서 엔비디아와 AMD 의 공급망 분석에 기반하여 투자유망 종목을 추천해주세요. 

# 제약 조건 
- 엔비디아와 AMD를 포함하여 반도체 업종의 기업과 관련된 뉴스, 리서치보고서, 재무데이터를 수집해서 분석합니다.  
- Firecrawl 과 Alpha Vantage를 통하여 반드시 최신 정보를 찾아야 합니다.
- 오늘은 [2025.12.18] 입니다.
- 보고서는 객관적인 데이터와 발표자료를 근거로 출력해주세요. 

# 출력형식 
- 반도체 업종에서 엔비디아와 AMD 의 공급 사슬 내 기업 중에서, 가장 큰 수혜가 예상되는 주식을 3개 선정합니다.
- 선정된 주식별로 기업개요, 주요 이슈를 정리합니다. 
- 선정된 기업별로 현재 주가와 향후 목표주가를 제안합니다. 
- 최종적으로 투자전망 측면에서 1개 기업을 선정하고, 선정 사유와 유의사항을 출력합니다.

# %%
# --- Prompt ---

위 프롬포트에 대하여 6번의 Firecrawl과 7번의 Alpha Vantage를 활용, 관련된 데이터를 수집했습니다.

![](https://static.wikidocs.net/images/page/310023/image_202512180948.png)

그 중  Alpha Vantage 에서 수집된 데이터의 예시를 보면 아래와 같이 TSMC의  회사 기본 소개와 더불어 다양한 재무정보(영업이익률, 순이익룰, 자기자본이익률 등)를 수집함을 알 수 있습니다.

# %%
# --- Prompt ---
{
    "Symbol": "TSM",
    "AssetType": "Common Stock",
    "Name": "Taiwan Semiconductor Manufacturing",
    "Description": "Taiwan Semiconductor Manufacturing Company, Limited (TSMC) stands as the foremost pure-play semiconductor foundry globally, headquartered in Hsinchu, Taiwan. Renowned for its cutting-edge manufacturing and design expertise, TSMC serves a wide array of industries, including telecommunications, high-performance computing, and automotive, playing a crucial role in the global technology ecosystem. The company's relentless focus on innovation is evident through its significant investments in advanced technologies and processes, ensuring its leadership in semiconductor fabrication. With a robust international presence and a diverse investor base, TSMC continues to forge strategic partnerships that enhance its influence and adaptability within the evolving semiconductor landscape.",
    "CIK": "1046179",
    "Exchange": "NYSE",
    "Currency": "USD",
    "Country": "USA",
    "Sector": "TECHNOLOGY",
    "Industry": "SEMICONDUCTORS",
    "Address": "HSINCHU SCIENCE PARK, HSINCHU CITY, TAIWAN, 300096",
    "OfficialSite": "https://www.tsmc.com",
    "FiscalYearEnd": "December",
    "LatestQuarter": "2025-09-30",
    "MarketCapitalization": "1487852536000",
    "EBITDA": "2484714078000",
    "PERatio": "29.67",
    "PEGRatio": "1.403",
    "BookValue": "6.15",
    "DividendPerShare": "20.5",
    "DividendYield": "0.0117",
    "EPS": "9.67",
    "RevenuePerShareTTM": "87.54",
    "ProfitMargin": "0.433",
    "OperatingMarginTTM": "0.506",
    "ReturnOnAssetsTTM": "0.166",
    "ReturnOnEquityTTM": "0.347",
    "RevenueTTM": "3631424995000",
    "GrossProfitTTM": "2141685285000",
    "DilutedEPSTTM": "9.67",
    "QuarterlyEarningsGrowthYOY": "0.391",
    "QuarterlyRevenueGrowthYOY": "0.303",
    "AnalystTargetPrice": "344.57",
    "AnalystRatingStrongBuy": "5",
    "AnalystRatingBuy": "10",
    "AnalystRatingHold": "2",
    "AnalystRatingSell": "0",
    "AnalystRatingStrongSell": "0",
    "TrailingPE": "29.67",
    "ForwardPE": "23.87",
    "PriceToSalesRatioTTM": "0.41",
    "PriceToBookRatio": "9.32",
    "EVToRevenue": "9.84",
    "EVToEBITDA": "13.72",
    "Beta": "1.267",
    "52WeekHigh": "313.13",
    "52WeekLow": "132.98",
    "50DayMovingAverage": "293.52",
    "200DayMovingAverage": "231.74",
    "SharesOutstanding": "5186505000",
    "SharesFloat": "24172484000",
    "PercentInsiders": "0.039",
    "PercentInstitutions": "16.268",
    "DividendDate": "2026-04-09",
    "ExDividendDate": "2026-03-17"
}

# %% [markdown]
# ### 3 2 3 바이브 코딩으로 직접 투자MCP 만들기.md

# %%
# --- Prompt ---
korea-stock-mcp/
├── package.json        # 패키지 정보 및 실행 스크립트
├── index.js                  # MCP 서버 진입점(핵심 로직: 데이터 수집/함수 노출)
└── README.md          # 사용법 및 주의사항

# %%
# --- Prompt ---

## 3) 코드 생성(LLM 보조 활용)

이제, MCP를 위한 코드를 처음부터 수작업으로 작성할 수도 있지만,  
본 과정에서는 초보자들도 따라할 수 있도록 **LLM에게 요구사항을 명확히 설명**하여  
코드를 개발하는 방식으로 진행합니다. 
아래와 같이 우리의 요구사항을 상세히 기술한 프롬프트로 시작합니다.

**초기권장 프롬프트**

# %%
# --- Prompt ---
네이버 금융에서 ETF, 테마, 시가총액 상위 종목 데이터 등을 추출하는 MCP 서버를 만들고자합니다.
MCP서버의 이름은 korea-stock-mcp 입니다.
1. Node.js 기반으로 index.js를 작성하고, package.json과 README.md까지 포함한 최소 패키지 구조를 생성해주세요.
2. index.js의 기능함수는 아래와 같습니다.
  - https://finance.naver.com/sise/etf.naver 에서 시가총액 순으로 ETF를 가져온다
  - https://finance.naver.com/sise/theme.naver 에서 전일대비 상승이 높은순으로 테마를 가져오고, 해당 테마의 주도주 종목명을 가져온다
  - https://finance.naver.com/sise/sise_market_sum.naver 에서 시가총액순으로 종목 이름과 현재가 정보를 가져온다
  - https://finance.naver.com/sise/dividend_list.naver 에서 배당수익률이 높은 순으로 종목정보를 가져온다
  - https://finance.naver.com/search/search.naver?query={종목명} 을 통해서 해당 종목에 대한 종목코드 정보를 가져온다
  - https://finance.naver.com/item/main.naver?code={종목코드} 방식을 통하여 해당 종목코드의 현재가 정보를 가져온다
3. 서버는 npx로 실행 가능해야 하며, MCP 프로토콜과 Claude가 함수 를 이해할 수 있도록 메타데이터를 노출해주세요.

+ 네이버 금융은 UTF-8이 아니라 EUC-KR(또는 CP949) 로 되어 있음을 참고해

# %%
# --- Prompt ---

의 프롬포트를 바탕으로 LLM이 생성해 준 코드를 기존 폴더내의 파일에 입력해줍니다.

![](https://static.wikidocs.net/images/page/307775/image_202602021259.png)


> 위 이미지와 같이 각각의 파일별 내용을 LLM이 출력해줍니다!

LLM이 작성해준 코드를 직접 복사붙여넣기로 진행하여도 되며,
이런 바이브 코딩으로 작성된 코드 결과물은 [Github 저장소](https://github.com/DrFirstLee/korea-stock-mcp) 에서 확인이 가능합니다! 
(LLM의 버젼에 따라 결과물이 조금씩 다를수 있으니 실습에는 위의 저장된 코드를 활용하길 권장합니다)

---

## 4) MCP 파일 테스트

이젠, 준비된 파일을 바탕으로 MCP 코드를 테스트해봅니다!
(챕터

# %%
# --- Prompt ---
npm install

# %%
# --- Prompt ---

![](https://static.wikidocs.net/images/page/307775/image_202602021304.png)
> 위 코드를 통해서 MCP를 위해 필요한 여러 패키지들이 자동으로 설치됩니다.

**서버 실행(테스트)**

이젠, 해당 모듈이 정상 작동하는지 확인해보아요

# %%
# --- Prompt ---
npm start

# %%
# --- Prompt ---

![](https://static.wikidocs.net/images/page/307775/image_202602021306.png)

> 위 와 같이 코드가 실행되면 정상입니다. 

---

## 5) Local 에서의 MCP  테스트 및 실행

이제, 준비된 코드를 바탕으로 내 Claude PC에서 MCP를 호출해봅니다!

**npm link로 패키지를 “글로벌 설치”처럼 만들기**

# %%
# --- Prompt ---
npm link

# %%
# --- Prompt ---

이 명령은:
- npm install -g 처럼 전역(global) 영역에 패키지를 설치하되,  
- 실제 파일은 C:\Users\DrFirst\notebook\korea-stock-mcp 를 심볼릭 링크로 연결하여 사용합니다.
- 동시에 package.json 의 "bin" 에 정의된 이름으로 전역 실행 파일도 만들어 줍니다.
- 즉, "bin": { "korea-stock-mcp": "index.js" } 덕분에 전역 PATH 어딘가에 korea-stock-mcp 라는 실행 파일(윈도우에선 .cmd)이 생깁니다.


이젠 어떤 디렉토리에서도

# %%
# --- Prompt ---
{
  "mcpServers": {
    "korea-stock-mcp": {
      "command": "npx",
      "args": ["korea-stock-mcp"],
      "env": {
        "NODE_NO_WARNINGS": "1"
      }
    }
  }
}

# %%
# --- Prompt ---

이후 claude PC를 종료 후 다시 실행해주면, 아래이미지와 같이

# %% [markdown]
# ### 3 2 4 나만의 투자 MCP 활용하기.md

# %%
# --- Prompt ---
{
  "mcpServers": {
      # 기존 데이터가 있다면: 아래 부분만 추가
    "korea-stock-mcp": {
      "command": "npx",
      "args": ["-y", "@drfirst/korea-stock-mcp@latest"]
    }
     # 기존 데이터가 있다면: 여기까지!
  }
}

# %%
# --- Prompt ---

수정이 완료되면 Claude를 다시 실행합니다.  
정상적으로 설정이 적용되었다면  
Claude 데스크톱 화면에서

# %%
# --- Prompt ---
korea-stock-mcp를 활용해서 오늘 주목받은 테마가 뭔지 알아봐

# %%
# --- Prompt ---

![](https://static.wikidocs.net/images/page/307819/image_202511171146.png)

> Claude는 MCP를 통해 최신 시장 데이터를 불러오고,  
> 해당 데이터를 기반으로 요약 및 분석 결과를 제시함을 확인할 수 있습니다.  

---

### 3. 투자 정보 수집하기

현재의 투자현황을 파악할때에는 시장의 지수를 파악하는것이 가장 빠르고 편리합니다.
최근에는 ETF 상품의 발달로 많이 거래되는 ETF를 바탕으로 시황을 빠르게 파악할 수 있습니다.

#### MCP에 연결된 ETF 정보를 바탕으로 먼저 시황을 살펴봅니다.

![](https://static.wikidocs.net/images/page/307819/image_202511191309.png)  
> 위와 같이 우리의 MCP를 활용해서 현재 거래가 많이되고 있는 ETF 정보를 조회해줍니다.

![](https://static.wikidocs.net/images/page/307819/image_202511191310.png)
> 그리고 해당 ETF 정보를 바탕으로 현재의 시황가 투자자들의 대응을 알 수 있습니다.


#### 이제, 금일에 주목받는 테마는 어떤 종목이 있는지 MCP를 통해서 알아봅니다.

![](https://static.wikidocs.net/images/page/307819/image_202511191313.png)
> 비록 금일의 장은 하락세이지만 여전히 일부 테마에서는 상승중임을 알 수 있습니다.

이 중에서
